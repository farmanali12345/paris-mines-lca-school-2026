# %% [markdown]
# # D3-01 Generating prospective databases with premise
#
# Audience:
# - Participants who already completed the Brightway and `ecoinvent` steps from Days 1 and 2.
#
# Prerequisites:
# - `paris-lca-course-2026` exists and contains `ecoinvent-3.12-cutoff`.
# - This notebook loads the repo-root `.env` file automatically and falls back to the embedded course IAM key if `IAM_FILES_KEY` is absent.
#
# Learning goals:
# - Build the course scenario list for REMIND-EU.
# - Run `premise.NewDatabase(...)` on `ecoinvent 3.12 cutoff`.
# - Write the generated scenario databases to Brightway.
# - Export a datapackage for optional `trails` work.

# %% [markdown]
# ## Outline
#
# 1. Confirm the input database and credentials.
# 2. Define the REMIND-EU scenarios used in the course.
# 3. Generate the updated scenario databases.
# 4. Write Brightway databases and a `trails` datapackage.
# 5. Check the exported artifacts.

# %%
import os
from pathlib import Path

import bw2data as bd
import pandas as pd
from dotenv import load_dotenv  # It helps to refresh the environmental data
from premise import NewDatabase, clear_cache

load_dotenv()

project_name = 'lca course paris 2026 primise'
source_db = 'ecoinvent-3.12-cutoff'
system_model = 'cutoff'
source_version = '3.12'
export_name = 'paris-trails-datapackage'
default_iam_key = 'tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo='

bd.projects.set_current(project_name)

biosphere_name = next((name for name in bd.databases if 'biosphere' in name and "3.12" in name), None)
iam_key = os.environ.get('IAM_FILES_KEY', default_iam_key)

print('Project        :', project_name)
print('Source database:', source_db)
print('Biosphere      :', biosphere_name)
print('IAM key in env :', bool(os.environ.get('IAM_FILES_KEY')))
print('Active IAM key :', iam_key)
# Out:
# Project        : lca course paris 2026 primise
# Source database: ecoinvent-3.12-cutoff
# Biosphere      : biosphere-3.12
# IAM key in env : True
# Active IAM key : tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=

# %%
pip install premise==2.4.4
# Out:
# Collecting premise==2.4.4
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\farman.ali\AppData\Local\anaconda3\envs\lca-course\Lib\site-packages\~xml'.
#   Downloading premise-2.4.4-py3-none-any.whl.metadata (23 kB)
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# Requirement already satisfied: numpy<2.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (1.26.4)
# edges 1.3.0 requires clipspy, which is not installed.
# Requirement already satisfied: bottleneck in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (1.6.0)
# Requirement already satisfied: bw2data in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (4.6.2)
# Requirement already satisfied: bw2io in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (0.9.17)
# Requirement already satisfied: ecoinvent_interface in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (3.1)
# Requirement already satisfied: constructive-geometries>=1.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (1.0)
# Requirement already satisfied: cryptography in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (47.0.0)
# Requirement already satisfied: datapackage in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (1.15.2)
# Requirement already satisfied: pandas<3.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (2.3.3)
# Requirement already satisfied: openpyxl<3.2.0,>=3.1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (3.1.5)
# Collecting lxml<6.0.0 (from premise==2.4.4)
#   Downloading lxml-5.4.0-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: platformdirs in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (4.9.6)
# Requirement already satisfied: premise_gwp in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (0.9.8)
# Requirement already satisfied: prettytable in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (3.17.0)
# Requirement already satisfied: pyarrow in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (24.0.0)
# Requirement already satisfied: pycountry in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (24.6.1)
# Requirement already satisfied: pyYaml in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (6.0.3)
# Requirement already satisfied: requests in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (2.33.1)
# Requirement already satisfied: schema in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (0.7.7)
# Requirement already satisfied: scipy<1.14.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (1.13.1)
# Requirement already satisfied: sparse>=0.14.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (0.17.0)
# Requirement already satisfied: wurst>=0.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (0.5.3)
# Requirement already satisfied: xarray<=2024.2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (2024.2.0)
# Requirement already satisfied: tqdm in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (4.67.3)
# Requirement already satisfied: unfold in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.4) (1.2.4)
# Requirement already satisfied: et_xmlfile in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from openpyxl<3.2.0,>=3.1.0->premise==2.4.4) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pandas<3.0.0->premise==2.4.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pandas<3.0.0->premise==2.4.4) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pandas<3.0.0->premise==2.4.4) (2026.2)
# Requirement already satisfied: packaging>=22 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from xarray<=2024.2.0->premise==2.4.4) (26.2)
# Requirement already satisfied: country_converter in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from constructive-geometries>=1.0.0->premise==2.4.4) (1.3.2)
# Requirement already satisfied: wrapt in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from constructive-geometries>=1.0.0->premise==2.4.4) (2.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0->premise==2.4.4) (1.17.0)
# Requirement already satisfied: numba>=0.49 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from sparse>=0.14.0->premise==2.4.4) (0.65.1)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from numba>=0.49->sparse>=0.14.0->premise==2.4.4) (0.47.0)
# Requirement already satisfied: docopt in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.4) (0.6.2)
# Requirement already satisfied: python-json-logger in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.4) (3.2.1)
# Requirement already satisfied: structlog in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.4) (25.5.0)
# Requirement already satisfied: toolz in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.4) (1.1.0)
# Requirement already satisfied: blinker in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (1.9.0)
# Requirement already satisfied: bw2parameters in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (1.1.0)
# Requirement already satisfied: bw_processing>=0.9.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (1.1.1)
# Requirement already satisfied: deepdiff~=7.0.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (7.0.1)
# Requirement already satisfied: deprecated in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (1.3.1)
# Requirement already satisfied: fsspec in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (2026.3.0)
# Requirement already satisfied: peewee>=4.0.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (4.0.5)
# Requirement already satisfied: pint in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (0.25.3)
# Requirement already satisfied: pydantic-settings in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (2.14.0)
# Requirement already satisfied: rapidfuzz in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (3.14.5)
# Requirement already satisfied: snowflake-id~=1.0.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (1.0.2)
# Requirement already satisfied: stats_arrays in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (1.0)
# Requirement already satisfied: typing_extensions in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (4.15.0)
# Requirement already satisfied: voluptuous in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.4) (0.16.0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from deepdiff~=7.0.1->bw2data->premise==2.4.4) (4.1.0)
# Requirement already satisfied: morefs in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw_processing>=0.9.5->bw2data->premise==2.4.4) (0.2.2)
# Requirement already satisfied: bw2calc>=2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.4) (2.4.0)
# Requirement already satisfied: bw_migrations>=0.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.4) (0.2)
# Requirement already satisfied: mrio_common_metadata in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.4) (0.2.1)
# Requirement already satisfied: pydantic in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.4) (2.13.3)
# Requirement already satisfied: SPARQLWrapper in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.4) (2.0.0)
# Requirement already satisfied: pyecospold in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.4) (4.0.0)
# Requirement already satisfied: randonneur>=0.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.4) (0.7.2)
# Requirement already satisfied: randonneur_data>=0.5.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.4) (0.7.2)
# Requirement already satisfied: xlrd in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.4) (2.0.2)
# Requirement already satisfied: xlsxwriter in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.4) (3.2.9)
# Requirement already satisfied: matrix_utils>=0.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2calc>=2.0->bw2io->premise==2.4.4) (0.7.1)
# Requirement already satisfied: asteval in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2parameters->bw2data->premise==2.4.4) (1.0.8)
# Requirement already satisfied: astunparse in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2parameters->bw2data->premise==2.4.4) (1.6.3)
# Requirement already satisfied: loguru in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from randonneur>=0.6->bw2io->premise==2.4.4) (0.7.3)
# Requirement already satisfied: cffi>=1.14 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from cryptography->premise==2.4.4) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from cffi>=1.14->cryptography->premise==2.4.4) (2.22)
# Requirement already satisfied: click>=6.7 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.4) (8.3.3)
# Requirement already satisfied: chardet>=3.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.4) (7.4.3)
# Requirement already satisfied: jsonschema>=2.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.4) (4.26.0)
# Requirement already satisfied: unicodecsv>=0.14 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.4) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.10 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.4) (3.1.1)
# Requirement already satisfied: tableschema>=1.12.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.4) (1.21.0)
# Requirement already satisfied: tabulator>=1.29 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.4) (1.53.5)
# Requirement already satisfied: colorama in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from click>=6.7->datapackage->premise==2.4.4) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.4) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.4) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.4) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.4) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.4) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.4) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.4) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.4) (2026.4.22)
# Requirement already satisfied: cached-property>=1.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.4) (1.5.2)
# Requirement already satisfied: isodate>=0.5.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.4) (0.7.2)
# Requirement already satisfied: rfc3986>=1.1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.4) (2.0.0)
# Requirement already satisfied: dataflows-tabulator>=1.54.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.4) (1.54.3)
# Requirement already satisfied: boto3>=1.9 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.4) (1.42.97)
# Requirement already satisfied: ijson>=3.0.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.4) (3.5.0)
# Requirement already satisfied: jsonlines>=1.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.4) (4.0.0)
# Requirement already satisfied: sqlalchemy>=0.9.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.4) (2.0.49)
# Requirement already satisfied: linear-tsv>=1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.4) (1.1.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.97 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from boto3>=1.9->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.4) (1.42.97)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from boto3>=1.9->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.4) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from boto3>=1.9->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.4) (0.16.1)
# Requirement already satisfied: greenlet>=1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from sqlalchemy>=0.9.6->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.4) (3.5.0)
# Requirement already satisfied: py7zr in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from ecoinvent_interface->premise==2.4.4) (1.1.2)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from loguru->randonneur>=0.6->bw2io->premise==2.4.4) (1.2.0)
# Requirement already satisfied: pyxlsb in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from mrio_common_metadata->bw2io->premise==2.4.4) (1.0.10)
# Requirement already satisfied: flexcache>=0.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pint->bw2data->premise==2.4.4) (0.3)
# Requirement already satisfied: flexparser>=0.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pint->bw2data->premise==2.4.4) (0.4)
# Requirement already satisfied: wcwidth in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from prettytable->premise==2.4.4) (0.6.0)
# Requirement already satisfied: texttable in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.4) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.20.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.4) (3.23.0)
# Requirement already satisfied: brotli>=1.2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.4) (1.2.0)
# Requirement already satisfied: psutil in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.4) (7.2.2)
# Requirement already satisfied: backports.zstd>=1.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.4) (1.3.0)
# Requirement already satisfied: pyppmd>=1.3.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.4) (1.3.1)
# Requirement already satisfied: pybcj>=1.0.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.4) (1.0.7)
# Requirement already satisfied: multivolumefile>=0.2.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.4) (0.2.3)
# Requirement already satisfied: inflate64>=1.0.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.4) (1.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic->bw2io->premise==2.4.4) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic->bw2io->premise==2.4.4) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic->bw2io->premise==2.4.4) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic-settings->bw2data->premise==2.4.4) (1.2.2)
# Requirement already satisfied: rdflib>=6.1.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from SPARQLWrapper->bw2io->premise==2.4.4) (7.6.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from rdflib>=6.1.1->SPARQLWrapper->bw2io->premise==2.4.4) (3.3.2)
# Requirement already satisfied: pyprind in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from unfold->premise==2.4.4) (2.11.3)
# Downloading premise-2.4.4-py3-none-any.whl (19.5 MB)
#    ---------------------------------------- 0.0/19.5 MB ? eta -:--:--
#    ------ --------------------------------- 3.4/19.5 MB 20.2 MB/s eta 0:00:01
#    --------------------------- ------------ 13.6/19.5 MB 34.3 MB/s eta 0:00:01
#    ---------------------------------------- 19.5/19.5 MB 35.2 MB/s  0:00:00
# Downloading lxml-5.4.0-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 3.8/3.8 MB 37.8 MB/s  0:00:00
# Installing collected packages: lxml, premise
#
#   Attempting uninstall: lxml
#
#     Found existing installation: lxml 6.1.0
#
#     Uninstalling lxml-6.1.0:
#
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#       Successfully uninstalled lxml-6.1.0
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#   Attempting uninstall: premise
#    ---------------------------------------- 0/2 [lxml]
#     Found existing installation: premise 2.4.3
#    ---------------------------------------- 0/2 [lxml]
#     Uninstalling premise-2.4.3:
#    ---------------------------------------- 0/2 [lxml]
#       Successfully uninstalled premise-2.4.3
#    ---------------------------------------- 0/2 [lxml]
#    -------------------- ------------------- 1/2 [premise]
#    -------------------- ------------------- 1/2 [premise]
#    -------------------- ------------------- 1/2 [premise]
#    -------------------- ------------------- 1/2 [premise]
#    -------------------- ------------------- 1/2 [premise]
#    ---------------------------------------- 2/2 [premise]
#
# Successfully installed lxml-5.4.0 premise-2.4.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import bw2io as bi
bi.restore_project_directory(
    fp="C:/Users/farman.ali/Download/brightway2-project-lca-course-paris-2026-premise-backup06-May-2026-12-01PM.tar"
    project_name="lca course paris 2026 primise")
# Out:
#   Cell In[1], line 3
#     fp="C:/Users/farman.ali/Download/brightway2-project-lca-course-paris-2026-premise-backup06-May-2026-12-01PM.tar"
#        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
list(bd.databases)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 list(bd.databases)
#
# NameError: name 'bd' is not defined

# %% [markdown]
# ## Step 1 - Define the course scenarios
#
# We compare two policy pathways across three years, always with `remind-eu` as the source of scenario data.

# %%
scenarios = [
    {'model': 'remind-eu', 'pathway': 'SSP2-NPi', 'year': 2025},
    {'model': 'remind-eu', 'pathway': 'SSP2-NPi', 'year': 2035},
    {'model': 'remind-eu', 'pathway': 'SSP2-NPi', 'year': 2050},
    # {'model': 'remind-eu', 'pathway': 'SSP2-PkBudg1000', 'year': 2025}, in principle, we do not need this one
    {'model': 'remind-eu', 'pathway': 'SSP2-PkBudg1000', 'year': 2035},
    {'model': 'remind-eu', 'pathway': 'SSP2-PkBudg1000', 'year': 2050},
]

scenario_table = pd.DataFrame(scenarios)
scenario_table
# Out:
#        model          pathway  year
# 0  remind-eu         SSP2-NPi  2025
# 1  remind-eu         SSP2-NPi  2035
# 2  remind-eu         SSP2-NPi  2050
# 3  remind-eu  SSP2-PkBudg1000  2035
# 4  remind-eu  SSP2-PkBudg1000  2050

# %%
# !pip install premise==2.4.3
# Out:
# Requirement already satisfied: premise==2.4.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (2.4.3)
# Requirement already satisfied: numpy<2.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.26.4)
# Requirement already satisfied: bottleneck in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.6.0)
# Requirement already satisfied: bw2data in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (4.6.2)
# Requirement already satisfied: bw2io in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (0.9.17)
# Requirement already satisfied: ecoinvent_interface in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (3.1)
# Requirement already satisfied: constructive-geometries>=1.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.0)
# Requirement already satisfied: cryptography in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (47.0.0)
# Requirement already satisfied: datapackage in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.15.2)
# Requirement already satisfied: pandas<3.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (2.3.3)
# Requirement already satisfied: platformdirs in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (4.9.6)
# Requirement already satisfied: premise_gwp in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (0.9.8)
# Requirement already satisfied: prettytable in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (3.17.0)
# Requirement already satisfied: pyarrow in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (24.0.0)
# Requirement already satisfied: pycountry in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (24.6.1)
# Requirement already satisfied: pyYaml in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (6.0.3)
# Requirement already satisfied: requests in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (2.33.1)
# Requirement already satisfied: schema in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (0.7.7)
# Requirement already satisfied: scipy<1.14.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.13.1)
# Requirement already satisfied: sparse>=0.14.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (0.17.0)
# Requirement already satisfied: wurst>=0.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (0.5.3)
# Requirement already satisfied: xarray<=2024.2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (2024.2.0)
# Requirement already satisfied: tqdm in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (4.67.3)
# Requirement already satisfied: unfold in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pandas<3.0.0->premise==2.4.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pandas<3.0.0->premise==2.4.3) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pandas<3.0.0->premise==2.4.3) (2026.2)
# Requirement already satisfied: packaging>=22 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from xarray<=2024.2.0->premise==2.4.3) (26.2)
# Requirement already satisfied: country_converter in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from constructive-geometries>=1.0.0->premise==2.4.3) (1.3.2)
# Requirement already satisfied: wrapt in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from constructive-geometries>=1.0.0->premise==2.4.3) (2.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0->premise==2.4.3) (1.17.0)
# Requirement already satisfied: numba>=0.49 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from sparse>=0.14.0->premise==2.4.3) (0.65.1)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from numba>=0.49->sparse>=0.14.0->premise==2.4.3) (0.47.0)
# Requirement already satisfied: docopt in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.3) (0.6.2)
# Requirement already satisfied: python-json-logger in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.3) (3.2.1)
# Requirement already satisfied: structlog in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.3) (25.5.0)
# Requirement already satisfied: toolz in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.3) (1.1.0)
# Requirement already satisfied: blinker in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.9.0)
# Requirement already satisfied: bw2parameters in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.1.0)
# Requirement already satisfied: bw_processing>=0.9.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.1.1)
# Requirement already satisfied: deepdiff~=7.0.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (7.0.1)
# Requirement already satisfied: deprecated in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.3.1)
# Requirement already satisfied: fsspec in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (2026.3.0)
# Requirement already satisfied: lxml in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (6.1.0)
# Requirement already satisfied: peewee>=4.0.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (4.0.5)
# Requirement already satisfied: pint in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (0.25.3)
# Requirement already satisfied: pydantic-settings in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (2.14.0)
# Requirement already satisfied: rapidfuzz in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (3.14.5)
# Requirement already satisfied: snowflake-id~=1.0.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.0.2)
# Requirement already satisfied: stats_arrays in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.0)
# Requirement already satisfied: typing_extensions in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (4.15.0)
# Requirement already satisfied: voluptuous in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (0.16.0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from deepdiff~=7.0.1->bw2data->premise==2.4.3) (4.1.0)
# Requirement already satisfied: morefs in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw_processing>=0.9.5->bw2data->premise==2.4.3) (0.2.2)
# Requirement already satisfied: bw2calc>=2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (2.4.0)
# Requirement already satisfied: bw_migrations>=0.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (0.2)
# Requirement already satisfied: mrio_common_metadata in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (0.2.1)
# Requirement already satisfied: openpyxl in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (3.1.5)
# Requirement already satisfied: pydantic in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (2.13.3)
# Requirement already satisfied: SPARQLWrapper in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (2.0.0)
# Requirement already satisfied: pyecospold in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (4.0.0)
# Requirement already satisfied: randonneur>=0.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (0.7.2)
# Requirement already satisfied: randonneur_data>=0.5.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (0.7.2)
# Requirement already satisfied: xlrd in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (2.0.2)
# Requirement already satisfied: xlsxwriter in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (3.2.9)
# Requirement already satisfied: matrix_utils>=0.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2calc>=2.0->bw2io->premise==2.4.3) (0.7.1)
# Requirement already satisfied: asteval in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2parameters->bw2data->premise==2.4.3) (1.0.8)
# Requirement already satisfied: astunparse in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2parameters->bw2data->premise==2.4.3) (1.6.3)
# Requirement already satisfied: loguru in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from randonneur>=0.6->bw2io->premise==2.4.3) (0.7.3)
# Requirement already satisfied: et_xmlfile in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from openpyxl->bw2io->premise==2.4.3) (2.0.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from cryptography->premise==2.4.3) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from cffi>=1.14->cryptography->premise==2.4.3) (2.22)
# Requirement already satisfied: click>=6.7 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (8.3.3)
# Requirement already satisfied: chardet>=3.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (7.4.3)
# Requirement already satisfied: jsonschema>=2.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (4.26.0)
# Requirement already satisfied: unicodecsv>=0.14 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.10 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (3.1.1)
# Requirement already satisfied: tableschema>=1.12.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (1.21.0)
# Requirement already satisfied: tabulator>=1.29 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (1.53.5)
# Requirement already satisfied: colorama in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from click>=6.7->datapackage->premise==2.4.3) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.3) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.3) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.3) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.3) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.3) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.3) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.3) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.3) (2026.4.22)
# Requirement already satisfied: cached-property>=1.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.3) (1.5.2)
# Requirement already satisfied: isodate>=0.5.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.3) (0.7.2)
# Requirement already satisfied: rfc3986>=1.1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.3) (2.0.0)
# Requirement already satisfied: dataflows-tabulator>=1.54.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.3) (1.54.3)
# Requirement already satisfied: boto3>=1.9 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (1.42.97)
# Requirement already satisfied: ijson>=3.0.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (3.5.0)
# Requirement already satisfied: jsonlines>=1.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (4.0.0)
# Requirement already satisfied: sqlalchemy>=0.9.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (2.0.49)
# Requirement already satisfied: linear-tsv>=1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (1.1.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.97 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from boto3>=1.9->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (1.42.97)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from boto3>=1.9->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from boto3>=1.9->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (0.16.1)
# Requirement already satisfied: greenlet>=1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from sqlalchemy>=0.9.6->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (3.5.0)
# Requirement already satisfied: py7zr in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from ecoinvent_interface->premise==2.4.3) (1.1.2)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from loguru->randonneur>=0.6->bw2io->premise==2.4.3) (1.2.0)
# Requirement already satisfied: pyxlsb in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from mrio_common_metadata->bw2io->premise==2.4.3) (1.0.10)
# Requirement already satisfied: flexcache>=0.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pint->bw2data->premise==2.4.3) (0.3)
# Requirement already satisfied: flexparser>=0.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pint->bw2data->premise==2.4.3) (0.4)
# Requirement already satisfied: wcwidth in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from prettytable->premise==2.4.3) (0.6.0)
# Requirement already satisfied: texttable in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.20.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (3.23.0)
# Requirement already satisfied: brotli>=1.2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.2.0)
# Requirement already satisfied: psutil in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (7.2.2)
# Requirement already satisfied: backports.zstd>=1.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.3.0)
# Requirement already satisfied: pyppmd>=1.3.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.3.1)
# Requirement already satisfied: pybcj>=1.0.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.0.7)
# Requirement already satisfied: multivolumefile>=0.2.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (0.2.3)
# Requirement already satisfied: inflate64>=1.0.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic->bw2io->premise==2.4.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic->bw2io->premise==2.4.3) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic->bw2io->premise==2.4.3) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic-settings->bw2data->premise==2.4.3) (1.2.2)
# Requirement already satisfied: rdflib>=6.1.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from SPARQLWrapper->bw2io->premise==2.4.3) (7.6.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from rdflib>=6.1.1->SPARQLWrapper->bw2io->premise==2.4.3) (3.3.2)
# Requirement already satisfied: pyprind in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from unfold->premise==2.4.3) (2.11.3)

# %% [markdown]
# ## Step 2 - Generate the prospective database object
#
# This step can take a while. Keep the notebook attached to the same `lca-course` kernel while it runs.
# The notebook loads `.env` from the repository root first, and only falls back to the embedded course IAM key if `IAM_FILES_KEY` is absent.

# %%
clear_cache()
if source_db not in bd.databases:
    raise ValueError(f'Missing source database: {source_db}')

ndb = NewDatabase(
    scenarios=scenarios,
    source_db=source_db,
    source_version=source_version,
    key=iam_key.encode(),
    system_model=system_model,
    biosphere_name=biosphere_name,
)

ndb.update()
print('Scenario update complete.')
# Out:
# Cache folder cleared!
# Cannot find the IAM scenario file at C:\Users\farman.ali\AppData\Local\anaconda3\envs\lca-course\Lib\site-packages\premise\data\iam_output_files\remind-eu_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at C:\Users\farman.ali\AppData\Local\anaconda3\envs\lca-course\Lib\site-packages\premise\data\iam_output_files\remind-eu_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at C:\Users\farman.ali\AppData\Local\anaconda3\envs\lca-course\Lib\site-packages\premise\data\iam_output_files\remind-eu_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at C:\Users\farman.ali\AppData\Local\anaconda3\envs\lca-course\Lib\site-packages\premise\data\iam_output_files\remind-eu_SSP2-PkBudg1000. Will check online.
# Cannot find the IAM scenario file at C:\Users\farman.ali\AppData\Local\anaconda3\envs\lca-course\Lib\site-packages\premise\data\iam_output_files\remind-eu_SSP2-PkBudg1000. Will check online.
# premise v.(2, 4, 3)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your Brightway project:                                   |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# Cannot find cached database. Will create one now for next time...
# Getting activity data
# 100%|██████████████████████████████████████████████████████████████████████████| 26533/26533 [00:04<00:00, 6177.10it/s]
# Adding exchange data to activities
# 100%|███████████████████████████████████████████████████████████████████████| 892943/892943 [00:34<00:00, 25606.65it/s]
# Filling out exchange data
# 100%|██████████████████████████████████████████████████████████████████████████| 26533/26533 [00:03<00:00, 7656.80it/s]
# Set missing location of datasets to global scope.
# Set missing location of production exchanges to scope of dataset.
# Correct missing location of technosphere exchanges.
# Correct missing flow categories for biosphere exchanges
# Remove empty exchanges.
# Remove uncertainty data.
# - Extracting inventories
# Cannot find cached inventories. Will create them now for next time...
# Importing default inventories...
#
# Importing C:\Users\farman.ali\AppData\Local\anaconda3\envs\lca-course\Lib\site-packages\premise\data\additional_inventories\lci-Carma-CCS.xlsx

# %% [markdown]
# ## Step 3 - Write Brightway databases and a datapackage
#
# We use deterministic database names so that later Brightway and Activity Browser comparisons stay readable.

# %%
# !pip install premise==2.4.3
# Out:
# Collecting premise==2.4.3
#   Downloading premise-2.4.3-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: numpy<2.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.26.4)
# Requirement already satisfied: bottleneck in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.6.0)
# Requirement already satisfied: bw2data in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (4.6.2)
# Requirement already satisfied: bw2io in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (0.9.17)
# Requirement already satisfied: ecoinvent_interface in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (3.1)
# Requirement already satisfied: constructive-geometries>=1.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.0)
# Requirement already satisfied: cryptography in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (47.0.0)
# Requirement already satisfied: datapackage in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.15.2)
# Requirement already satisfied: pandas<3.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (2.3.3)
# Requirement already satisfied: platformdirs in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (4.9.6)
# Requirement already satisfied: premise_gwp in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (0.9.8)
# Requirement already satisfied: prettytable in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (3.17.0)
# Requirement already satisfied: pyarrow in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (24.0.0)
# Requirement already satisfied: pycountry in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (24.6.1)
# Requirement already satisfied: pyYaml in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (6.0.3)
# Requirement already satisfied: requests in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (2.33.1)
# Requirement already satisfied: schema in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (0.7.7)
# Requirement already satisfied: scipy<1.14.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.13.1)
# Requirement already satisfied: sparse>=0.14.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (0.17.0)
# Requirement already satisfied: wurst>=0.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (0.5.3)
# Requirement already satisfied: xarray<=2024.2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (2024.2.0)
# Requirement already satisfied: tqdm in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (4.67.3)
# Requirement already satisfied: unfold in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from premise==2.4.3) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pandas<3.0.0->premise==2.4.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pandas<3.0.0->premise==2.4.3) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pandas<3.0.0->premise==2.4.3) (2026.2)
# Requirement already satisfied: packaging>=22 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from xarray<=2024.2.0->premise==2.4.3) (26.2)
# Requirement already satisfied: country_converter in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from constructive-geometries>=1.0.0->premise==2.4.3) (1.3.2)
# Requirement already satisfied: wrapt in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from constructive-geometries>=1.0.0->premise==2.4.3) (2.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0->premise==2.4.3) (1.17.0)
# Requirement already satisfied: numba>=0.49 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from sparse>=0.14.0->premise==2.4.3) (0.65.1)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from numba>=0.49->sparse>=0.14.0->premise==2.4.3) (0.47.0)
# Requirement already satisfied: docopt in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.3) (0.6.2)
# Requirement already satisfied: python-json-logger in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.3) (3.2.1)
# Requirement already satisfied: structlog in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.3) (25.5.0)
# Requirement already satisfied: toolz in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from wurst>=0.4->premise==2.4.3) (1.1.0)
# Requirement already satisfied: blinker in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.9.0)
# Requirement already satisfied: bw2parameters in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.1.0)
# Requirement already satisfied: bw_processing>=0.9.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.1.1)
# Requirement already satisfied: deepdiff~=7.0.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (7.0.1)
# Requirement already satisfied: deprecated in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.3.1)
# Requirement already satisfied: fsspec in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (2026.3.0)
# Requirement already satisfied: lxml in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (6.1.0)
# Requirement already satisfied: peewee>=4.0.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (4.0.5)
# Requirement already satisfied: pint in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (0.25.3)
# Requirement already satisfied: pydantic-settings in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (2.14.0)
# Requirement already satisfied: rapidfuzz in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (3.14.5)
# Requirement already satisfied: snowflake-id~=1.0.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.0.2)
# Requirement already satisfied: stats_arrays in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (1.0)
# Requirement already satisfied: typing_extensions in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (4.15.0)
# Requirement already satisfied: voluptuous in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2data->premise==2.4.3) (0.16.0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from deepdiff~=7.0.1->bw2data->premise==2.4.3) (4.1.0)
# Requirement already satisfied: morefs in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw_processing>=0.9.5->bw2data->premise==2.4.3) (0.2.2)
# Requirement already satisfied: bw2calc>=2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (2.4.0)
# Requirement already satisfied: bw_migrations>=0.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (0.2)
# Requirement already satisfied: mrio_common_metadata in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (0.2.1)
# Requirement already satisfied: openpyxl in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (3.1.5)
# Requirement already satisfied: pydantic in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (2.13.3)
# Requirement already satisfied: SPARQLWrapper in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (2.0.0)
# Requirement already satisfied: pyecospold in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (4.0.0)
# Requirement already satisfied: randonneur>=0.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (0.7.2)
# Requirement already satisfied: randonneur_data>=0.5.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (0.7.2)
# Requirement already satisfied: xlrd in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (2.0.2)
# Requirement already satisfied: xlsxwriter in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2io->premise==2.4.3) (3.2.9)
# Requirement already satisfied: matrix_utils>=0.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2calc>=2.0->bw2io->premise==2.4.3) (0.7.1)
# Requirement already satisfied: asteval in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2parameters->bw2data->premise==2.4.3) (1.0.8)
# Requirement already satisfied: astunparse in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from bw2parameters->bw2data->premise==2.4.3) (1.6.3)
# Requirement already satisfied: loguru in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from randonneur>=0.6->bw2io->premise==2.4.3) (0.7.3)
# Requirement already satisfied: et_xmlfile in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from openpyxl->bw2io->premise==2.4.3) (2.0.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from cryptography->premise==2.4.3) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from cffi>=1.14->cryptography->premise==2.4.3) (2.22)
# Requirement already satisfied: click>=6.7 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (8.3.3)
# Requirement already satisfied: chardet>=3.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (7.4.3)
# Requirement already satisfied: jsonschema>=2.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (4.26.0)
# Requirement already satisfied: unicodecsv>=0.14 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.10 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (3.1.1)
# Requirement already satisfied: tableschema>=1.12.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (1.21.0)
# Requirement already satisfied: tabulator>=1.29 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from datapackage->premise==2.4.3) (1.53.5)
# Requirement already satisfied: colorama in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from click>=6.7->datapackage->premise==2.4.3) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.3) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.3) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.3) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from jsonschema>=2.5->datapackage->premise==2.4.3) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.3) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.3) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.3) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from requests->premise==2.4.3) (2026.4.22)
# Requirement already satisfied: cached-property>=1.5 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.3) (1.5.2)
# Requirement already satisfied: isodate>=0.5.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.3) (0.7.2)
# Requirement already satisfied: rfc3986>=1.1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.3) (2.0.0)
# Requirement already satisfied: dataflows-tabulator>=1.54.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from tableschema>=1.12.1->datapackage->premise==2.4.3) (1.54.3)
# Requirement already satisfied: boto3>=1.9 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (1.42.97)
# Requirement already satisfied: ijson>=3.0.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (3.5.0)
# Requirement already satisfied: jsonlines>=1.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (4.0.0)
# Requirement already satisfied: sqlalchemy>=0.9.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (2.0.49)
# Requirement already satisfied: linear-tsv>=1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (1.1.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.97 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from boto3>=1.9->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (1.42.97)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from boto3>=1.9->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from boto3>=1.9->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (0.16.1)
# Requirement already satisfied: greenlet>=1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from sqlalchemy>=0.9.6->dataflows-tabulator>=1.54.1->tableschema>=1.12.1->datapackage->premise==2.4.3) (3.5.0)
# Requirement already satisfied: py7zr in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from ecoinvent_interface->premise==2.4.3) (1.1.2)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from loguru->randonneur>=0.6->bw2io->premise==2.4.3) (1.2.0)
# Requirement already satisfied: pyxlsb in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from mrio_common_metadata->bw2io->premise==2.4.3) (1.0.10)
# Requirement already satisfied: flexcache>=0.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pint->bw2data->premise==2.4.3) (0.3)
# Requirement already satisfied: flexparser>=0.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pint->bw2data->premise==2.4.3) (0.4)
# Requirement already satisfied: wcwidth in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from prettytable->premise==2.4.3) (0.6.0)
# Requirement already satisfied: texttable in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.20.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (3.23.0)
# Requirement already satisfied: brotli>=1.2.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.2.0)
# Requirement already satisfied: psutil in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (7.2.2)
# Requirement already satisfied: backports.zstd>=1.0.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.3.0)
# Requirement already satisfied: pyppmd>=1.3.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.3.1)
# Requirement already satisfied: pybcj>=1.0.6 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.0.7)
# Requirement already satisfied: multivolumefile>=0.2.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (0.2.3)
# Requirement already satisfied: inflate64>=1.0.4 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from py7zr->ecoinvent_interface->premise==2.4.3) (1.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic->bw2io->premise==2.4.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic->bw2io->premise==2.4.3) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic->bw2io->premise==2.4.3) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from pydantic-settings->bw2data->premise==2.4.3) (1.2.2)
# Requirement already satisfied: rdflib>=6.1.1 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from SPARQLWrapper->bw2io->premise==2.4.3) (7.6.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from rdflib>=6.1.1->SPARQLWrapper->bw2io->premise==2.4.3) (3.3.2)
# Requirement already satisfied: pyprind in c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages (from unfold->premise==2.4.3) (2.11.3)
# Downloading premise-2.4.3-py3-none-any.whl (19.5 MB)
#    ---------------------------------------- 0.0/19.5 MB ? eta -:--:--
#    - -------------------------------------- 0.8/19.5 MB 5.6 MB/s eta 0:00:04
#    --- ------------------------------------ 1.8/19.5 MB 5.9 MB/s eta 0:00:03
#    ------ --------------------------------- 3.1/19.5 MB 5.8 MB/s eta 0:00:03
#    --------- ------------------------------ 4.5/19.5 MB 6.1 MB/s eta 0:00:03
#    ------------ --------------------------- 6.0/19.5 MB 6.5 MB/s eta 0:00:03
#    --------------- ------------------------ 7.6/19.5 MB 6.7 MB/s eta 0:00:02
#    ------------------- -------------------- 9.4/19.5 MB 7.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 11.5/19.5 MB 7.4 MB/s eta 0:00:02
#    --------------------------- ------------ 13.6/19.5 MB 7.6 MB/s eta 0:00:01
#    -------------------------------- ------- 16.0/19.5 MB 8.0 MB/s eta 0:00:01
#    ------------------------------------- -- 18.1/19.5 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 19.5/19.5 MB 8.2 MB/s  0:00:02
# Installing collected packages: premise
#   Attempting uninstall: premise
#     Found existing installation: premise 2.4.2
#     Uninstalling premise-2.4.2:
#       Successfully uninstalled premise-2.4.2
# Successfully installed premise-2.4.3

# %%
ndb.write_db_to_brightway()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ndb.write_db_to_brightway()
#
# NameError: name 'ndb' is not defined

# %% [markdown]
# ## Step 4 - Check the exported artifacts

# %%
export_path = Path.cwd() / 'export' / 'datapackage' / f'{export_name}.zip'

print('Datapackage path:', export_path)
print('Exists          :', export_path.exists())
print('Generated DBs   :', bd.databases)
