# %% [markdown]
# # D1-04 First LCA from demand to score in Brightway
#
# This notebook is the main Day 1 milestone: we bootstrap the course project from a prepared Brightway archive, import the bundled BAFU workbook, inspect the resulting database, and run a first LCA.
#
# The hands-on exercises use BAFU throughout the course. We use `ecoinvent-3.10-biosphere` only as a convenient starting project because it already contains `biosphere3` and a populated set of LCIA methods.

# %% [markdown]
# ## Learning goals
#
# - Install or switch to the course `brightway` project from a prepared archive.
# - Import the bundled BAFU workbook with `bw2io.ExcelImporter`.
# - Understand the role of strategies, biosphere matching, statistics, and database writing.
# - Inspect the LCIA methods that are already available in the project.
# - Inspect the imported database by searching for activities and exchanges.
# - Run a first LCA score with an explicitly chosen activity and method.
# - Recognize how the Day 2 `ecoinvent 3.12 cutoff` import fits into the same overall workflow.

# %% [markdown]
# ## Background references
#
# - Mutel, C. (2017). *Brightway: An open source framework for life cycle assessment*. Journal of Open Source Software, 2(12), 236. https://doi.org/10.21105/joss.00236
# - Database of the Swiss Federal Administration, FOEN:20XY, Federal Office for the Environment, 2025.

# %% [markdown]
# ## 1) Install or switch to the course project
#
# We start from a prepared Brightway project archive instead of building `biosphere3` and the LCIA methods from scratch.
#
# The call `bi.remote.install_project('ecoinvent-3.10-biosphere', project_name)` downloads the archive on first use, restores it as a new project, and gives us a project that already contains `biosphere3` and many LCIA methods.
# If the project already exists locally, we simply switch to it.

# %%
from pathlib import Path
from pprint import pprint

import numpy as np
import pandas as pd
import bw2calc as bc
import bw2data as bd
import bw2io as bi

# this is just to let dataframe print fully
pd.set_option('display.max_colwidth', None)

# %%
# let's choose a project name
project_name = "paris-lca-course-2026"

# and make a list of existing projects
existing_projects = [project.name for project in bd.projects]

# %%
# if the project is already part of the projects' list, then our project already exists
# in this case, we only need to "switch" to it
if project_name in existing_projects:
    bd.projects.set_current(project_name)
    print('Switched to existing project:', bd.projects.current)

# if not, then we create it
else:
    bi.remote.install_project("ecoinvent-3.10-biosphere", project_name)
    # and we switch to it
    bd.projects.set_current(project_name)
    print('Installed and switched to project:', bd.projects.current)
# Out:
# Downloading ecoinvent-3.10-biosphere.tar.gz to C:\Users\farman.ali\AppData\Local\pylca\Brightway3\bw2io_cache_dir\ecoinvent-3.10-biosphere.tar.gz
# 17465344it [00:02, 8440348.03it/s]
# Restoring project backup archive - this could take a few minutes...
# Restored project: paris-lca-course-2026
# 11:59:59+0200 [info     ] Applying automatic update: 4.0 database search directories FTS5
# 11:59:59+0200 [info     ] Reindexing database ecoinvent-3.10-biosphere
# Installed and switched to project: paris-lca-course-2026

# %%
# this is needed later when importing LCI databases
bi.create_core_migrations()

print('Databases available now:', list(bd.databases))
print('LCIA methods available now:', len(bd.methods))
# Out:
# Databases available now: ['ecoinvent-3.10-biosphere']
# LCIA methods available now: 668

# %% [markdown]
# Let's check the size of `ecoinvent-3.10-biosphere`

# %%
len(bd.Database("ecoinvent-3.10-biosphere"))
# Out:
# 4362

# %% [markdown]
# The prepared project already contains the core biosphere database and a large set of LCIA methods.
# So the hands-on import work in this notebook is focused on the BAFU technosphere database.

# %% [markdown]
# ## 2) Confirm the bundled BAFU workbook
#
# The BAFU database we will be using is available as a workbook, contained in this repository:
#
# - `data/lci-bafu.xlsx`

# %%
bafu_file = Path('../../data/lci-bafu.xlsx')

print('Workbook path:', bafu_file.resolve())
print('Found:', bafu_file.exists())
if bafu_file.exists():
    print('Workbook size [MB]:', round(bafu_file.stat().st_size / 1024 / 1024, 2))
# Out:
# Workbook path: C:\Users\farman.ali\GitHub\paris-mines-lca-school-2026\data\lci-bafu.xlsx
# Found: True
# Workbook size [MB]: 29.47

# %% [markdown]
# ## 3) Import pipeline: `ExcelImporter` -> strategies -> biosphere matching -> statistics -> database writing
#
# This is the import sequence to understand in this notebook:
#
# 1. Create an `ExcelImporter` object from the workbook path.
# 2. Apply the standard import strategies (data cleanup, mostly).
# 3. Match biosphere flows against `biosphere3`.
# 4. Check import statistics and unlinked exchanges.
# 5. Write the database to the current project.

# %%
database_name = 'bafu'

# create the ExcelImporter object
importer = bi.ExcelImporter(str(bafu_file))
print('Importer type:', type(importer).__name__)
print('Raw datasets loaded:', len(importer.data))
# Out:
# Extracted 1 worksheets in 114.00 seconds
# Importer type: ExcelImporter
# Raw datasets loaded: 11747

# %%
# data cleanup
importer.apply_strategies()
print('Applied import strategies.')
# Out:
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_restore_temporal_distributions
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 15 strategies in 12.38 seconds
# Applied import strategies.

# %%
importer.match_database(fields=('name', 'reference product', 'location'))
# Out:
# Applying strategy: link_iterable_by_fields

# %%
# now, we try to match the biosphere exchanges with the flows of the `biosphere` database
# on the basis of 'name', 'unit', 'categories'
importer.match_database('ecoinvent-3.10-biosphere', fields=('name', 'unit', 'categories'))
print('Matched biosphere exchanges against biosphere3.')
# Out:
# Applying strategy: link_iterable_by_fields
# Matched biosphere exchanges against biosphere3.

# %%
# we check the status of exchanges linking
importer.statistics()
# Out:
# Graph statistics for `bafu` importer:
# 11747 graph nodes:
# 	processwithreferenceproduct: 11747
# 408975 graph edges:
# 	biosphere: 284445
# 	technosphere: 112783
# 	production: 11747
# 284445 edges to the following databases:
# 	ecoinvent-3.10-biosphere: 284445
# 19808 unique unlinked edges (124530 total):
# 	technosphere: 8061
# 	production: 11747
# (11747, 408975, 124530, 0)

# %% [markdown]
# `0 unique unlinked edges (0 total)` is usually the sweet message you want to see.
# This means we can go ahead and write the database to the project.

# %%
importer.write_database()
# Out:
# 12:18:30+0200 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
# 100%|███████████████████████████████████████████████████████████████████████████| 11747/11747 [00:23<00:00, 504.07it/s]
# 12:18:54+0200 [info     ] Vacuuming database
# Created database: bafu

# %% [markdown]
# ## 4) Inspect the LCIA methods already available in the project
#
# Because the project archive came from `ecoinvent-3.10-biosphere`, the LCIA methods are already in place.
# So, unlike the previous version of this notebook, we do not import LCIA methods from local Excel files here.

# %%
preferred_method = ('EF v3.1', 'climate change', 'global warming potential (GWP100)')

print('Databases available:', list(bd.databases))
print('Number of LCIA methods available:', len(bd.methods))
print('Preferred climate-change method available:', preferred_method in bd.methods)
# Out:
# Databases available: ['ecoinvent-3.10-biosphere', 'bafu']
# Number of LCIA methods available: 668
# Preferred climate-change method available: True

# %% [markdown]
# Let's quickly inspect a few available methods before choosing one for the first LCA.

# %%
sample_methods = sorted(bd.methods)[:10]
climate_methods = [m for m in sorted(bd.methods) if 'climate change' in ' | '.join(m).lower()]

print('First 10 LCIA methods in the project:')
for method in sample_methods:
    print('-', ' | '.join(method))

print('\nFirst climate-related methods:')
for method in climate_methods[:10]:
    print('-', ' | '.join(method))
# Out:
# First 10 LCIA methods in the project:
# - CML v4.8 2016 | acidification | acidification (incl. fate, average Europe total, A&B)
# - CML v4.8 2016 | climate change | global warming potential (GWP100)
# - CML v4.8 2016 | ecotoxicity: freshwater | freshwater aquatic ecotoxicity (FAETP inf)
# - CML v4.8 2016 | ecotoxicity: marine | marine aquatic ecotoxicity (MAETP inf)
# - CML v4.8 2016 | ecotoxicity: terrestrial | terrestrial ecotoxicity (TETP inf)
# - CML v4.8 2016 | energy resources: non-renewable | abiotic depletion potential (ADP): fossil fuels
# - CML v4.8 2016 | eutrophication | eutrophication (fate not incl.)
# - CML v4.8 2016 | human toxicity | human toxicity (HTP inf)
# - CML v4.8 2016 | material resources: metals/minerals | abiotic depletion potential (ADP): elements (ultimate reserves)
# - CML v4.8 2016 | ozone depletion | ozone layer depletion (ODP steady state)
#
# First climate-related methods:
# - CML v4.8 2016 | climate change | global warming potential (GWP100)
# - CML v4.8 2016 no LT | climate change no LT | global warming potential (GWP100) no LT
# - EF v3.0 | climate change | global warming potential (GWP100)
# - EF v3.0 | climate change: biogenic | global warming potential (GWP100)
# - EF v3.0 | climate change: fossil | global warming potential (GWP100)
# - EF v3.0 | climate change: land use and land use change | global warming potential (GWP100)
# - EF v3.0 EN15804 | climate change | global warming potential (GWP100)
# - EF v3.0 EN15804 | climate change: GHG (EPD PCR) | global warming potential (GWP100)
# - EF v3.0 EN15804 | climate change: biogenic | global warming potential (GWP100)
# - EF v3.0 EN15804 | climate change: fossil | global warming potential (GWP100)

# %% [markdown]
# ### REMINDER: how to inspect an LCIA method?

# %%
my_method = bd.methods.random()
my_method
# Out:
# ('EF v3.1 EN15804', 'climate change', 'global warming potential (GWP100)')

# %%
method_obj = bd.Method(my_method)
method_data = method_obj.load()

# %%
print('Method metadata:')
pprint(method_obj.metadata)
# Out:
# Method metadata:
# {'abbreviation': 'ef-v31-en15804cg.6c8284396aeb7522ad52dd060c887bef',
#  'database': 'ecoinvent-3.10-biosphere',
#  'ecoinvent_version': '3.10',
#  'filepath': '/Users/cmutel/Library/Application '
#              'Support/EcoinventInterface/cache/ecoinvent '
#              '3.10_LCIA_implementation/LCIA Implementation 3.10.xlsx',
#  'geocollections': ['world'],
#  'num_cfs': 189,
#  'unit': 'kg CO2-Eq'}

# %%
# an empty list, to store the results
lcia_data = []

for flow_id, cf in method_data:
    flow = bd.get_activity(flow_id)
    lcia_data.append(
        [
            flow["name"],
            cf
        ]
    )

pd.DataFrame(lcia_data, columns=["flow name", "cf"])
# Out:
#                      flow name       cf
# 0    1,1,1,2-Tetrafluoroethane   1530.0
# 1    1,1,1,2-Tetrafluoroethane   1530.0
# 2    1,1,1,2-Tetrafluoroethane   1530.0
# 3    1,1,1,2-Tetrafluoroethane   1530.0
# 4        1,1,1-Trichloroethane    161.0
# ..                         ...      ...
# 184     Trichlorofluoromethane   6230.0
# 185           Trifluoromethane  14600.0
# 186           Trifluoromethane  14600.0
# 187           Trifluoromethane  14600.0
# 188           Trifluoromethane  14600.0
#
# [189 rows x 2 columns]

# %% [markdown]
# ## 5) Import your own LCIA method

# %% [markdown]
# We will use bw2io.LCIAExcelImporter to import a user-defined LCIA method file.
# You can find those files under `data/LCIA methods`. We will import `01__acidification__accumulated_exceedance_AE.xlsx`.

# %%
lcia_method_file = Path('../../data/LCIA methods/01__acidification__accumulated_exceedance_AE.xlsx')

importer = bi.ExcelLCIAImporter(
    str(lcia_method_file),
    name=("EF 3.0", "Acidification"),
    description="Some method about ocean acidification",
    unit="kg SO2-eq."
)

# %%
# data cleanup
importer.apply_strategies()
# Out:
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.13 seconds

# %%
# let's check if we have any unlinked CFs
importer.statistics()
# Out:
# 1 methods
# 19 cfs
# 0 unlinked cfs
# (1, 19, 0)

# %%
# we're good to go!
importer.write_methods()
# Out:
# Wrote 1 LCIA methods with 19 characterization factors

# %%
# let's confirm that our method is available
("EF 3.0", "Acidification") in bd.methods
# Out:
# True

# %%
# let's inspect it
acid_method = bd.Method(("EF 3.0", "Acidification"))
pprint(acid_method.metadata)
# Out:
# {'abbreviation': 'ef-30a.33e899d02d0b2714248f9d3f8c74391d',
#  'description': 'Some method about ocean acidification',
#  'filename': '01__acidification__accumulated_exceedance_AE.xlsx',
#  'geocollections': ['world'],
#  'num_cfs': 19,
#  'unit': 'kg SO2-eq.'}

# %%
for flow_id, cf in acid_method.load():
    flow = bd.get_activity(flow_id)
    print(flow["name"], cf)
# Out:
# Ammonia 3.02
# Nitrogen oxides 0.74
# Nitrogen oxides 0.74
# Ammonia 3.02
# Sulfur trioxide 1.04821
# Sulfur trioxide 1.04821
# Sulfur trioxide 1.04821
# Sulfur dioxide 1.31
# Sulfur dioxide 1.31
# Ammonia 3.02
# Nitrogen oxides 0.74
# Sulfur dioxide 1.31
# Sulfur dioxide 1.31
# Nitrogen oxides 0.74
# Nitrogen oxides 0.74
# Sulfur trioxide 1.04821
# Sulfur oxides 1.31
# Nitric oxide 1.13467
# Ammonia 3.02

# %% [markdown]
# ## 6) Inspect the imported database
#
# Now we reconnect the import workflow from the previous notebooks: project -> database -> activity -> exchange.
#
# A good way to start is to search the database by name, then refine with additional filters such as `location`.

# %%
db = bd.Database("bafu")
print('Number of activities in bafu:', len(db))
# Out:
# Number of activities in bafu: 11747

# %%
starter_queries = [
    'operation, passenger car, petrol',
    'passenger car, gasoline',
    'gasoline',
]
starter_hits = []
used_query = None

for query in starter_queries:
    hits = db.search(query, limit=10)
    if hits:
        starter_hits = hits
        used_query = query
        break

print('Search query used:', used_query)

pd.DataFrame(
    [
        {
            'name': act['name'],
            'location': act.get('location'),
            'unit': act.get('unit'),
        }
        for act in starter_hits
    ]
)
# Out:
# Search query used: operation, passenger car, petrol
#                                                                                name  \
# 0  Operation, passenger car, petrol, 15% vol. ETBE with ethanol from biomass, EURO4
# 1   Operation, passenger car, petrol, 4% vol. ETBE with ethanol from biomass, EURO4
#
#   location       unit
# 0       CH  kilometer
# 1       CH  kilometer

# %% [markdown]
# We can use `bw2data.search()` to look for activities (this, naturally, works also to search the `biosphere` database).
# You can always display the arguments and teh docstrings of a function like so:

# %%
db.search?
# db.search() is quite complex if it needs to be...
# Out:
# Signature: db.search(string, **kwargs)
# Docstring:
# Search this database for ``string``.
#
# The searcher include the following fields:
#
# * name
# * comment
# * categories
# * location
# * reference product
#
# ``string`` can include wild cards, e.g. ``"trans*"``.
#
# By default, the ``name`` field is given the most weight. The full weighting set is called the ``boost`` dictionary, and the default weights are::
#
#     {
#         "name": 5,
#         "comment": 1,
#         "product": 3,
#         "categories": 2,
#         "location": 3
#     }
#
# Optional keyword arguments:
#
# * ``limit``: Number of results to return.
# * ``boosts``: Dictionary of field names and numeric boosts - see default boost values above. New values must be in the same format, but with different weights.
# * ``filter``: Dictionary of criteria that search results must meet, e.g. ``{'categories': 'air'}``. Keys must be one of the above fields.
# * ``mask``: Dictionary of criteria that exclude search results. Same format as ``filter``.
# * ``facet``: Field to facet results. Must be one of ``name``, ``product``, ``categories``, ``location``, or ``database``.
# * ``proxy``: Return ``Activity`` proxies instead of dictionary index Models. Default is ``True``.
#
# Returns a list of ``Activity`` datasets.
# File:      c:\users\farman.ali\appdata\local\anaconda3\envs\lca-course\lib\site-packages\bw2data\backends\base.py
# Type:      method

# %%
db.search(
    "gasoline",
    filter={
        "location": "RER",
        "reference product": "car"
    },
    limit=10
)
# Out:
# ['Transport, passenger car, gasoline, fleet average' (kilometer, CH, None),
#  'Transport, passenger car, gasoline, fleet average' (kilometer, RER, None),
#  'Transport, Motorbike, gasoline, 2020 fleet average' (kilometer, CH, None),
#  'Fuel supply for gasoline vehicles' (kilogram, CH, None),
#  'Fuel supply for gasoline vehicles' (kilogram, RER, None),
#  'Passenger car, gasoline, Medium, 2016, EURO-6ab' (unit, RER, None),
#  'Passenger car, gasoline, Compact, 2018, EURO-6c' (unit, RER, None),
#  'Passenger car, gasoline, Compact, 2008, EURO-4' (unit, RER, None),
#  'Passenger car, gasoline, Large, 2018, EURO-6c' (unit, RER, None),
#  'Passenger car, gasoline, Compact, 2003, EURO-3' (unit, RER, None)]

# %% [markdown]
# A `search` gets you close quickly. To be more explicit, you can iterate through the database yourself and combine several criteria in a list comprehension.

# %%
gasoline_car_candidates = [
    act
    for act in db
    if 'gasoline' in act['name'].lower()
    and any(term in act['reference product'].lower() for term in ['car', 'gasoline'])
    and act["location"] == "RER"
    and act["unit"] == "kilometer"
]

pd.DataFrame(
    [
        {
            'name': act['name'],
            'location': act.get('location'),
            'unit': act.get('unit'),
        }
        for act in gasoline_car_candidates[:10]
    ]
)
# Out:
#                                                                          name  \
# 0                   Transport, passenger car, gasoline, Compact, 2013, EURO-5
# 1  Transport, passenger car, plugin gasoline hybrid, Large SUV, 2021, EURO-6d
# 2     Transport, passenger car, plugin gasoline hybrid, Medium, 2018, EURO-6c
# 3              Transport, passenger car, gasoline, Medium, 2019, EURO-6d-TEMP
# 4         Transport, passenger car, gasoline hybrid, Large SUV, 2018, EURO-6c
# 5   Transport, passenger car, plugin gasoline hybrid, Large SUV, 2013, EURO-5
# 6               Transport, passenger car, gasoline, Large SUV, 2016, EURO-6ab
# 7                           Transport, passenger car, gasoline, fleet average
# 8      Transport, passenger car, plugin gasoline hybrid, Medium, 2013, EURO-5
# 9    Transport, passenger car, plugin gasoline hybrid, Compact, 2018, EURO-6c
#
#   location       unit
# 0      RER  kilometer
# 1      RER  kilometer
# 2      RER  kilometer
# 3      RER  kilometer
# 4      RER  kilometer
# 5      RER  kilometer
# 6      RER  kilometer
# 7      RER  kilometer
# 8      RER  kilometer
# 9      RER  kilometer

# %% [markdown]
# Geography filters are often more reliable than free-text search alone. For example, you can ask for passenger-car activities in Switzerland (`CH`), Europe (`RER`), or global datasets (`GLO`).

# %%
car_by_location = [
    act
    for act in db
    if 'passenger car' in act['name'].lower()
    and act.get('location') in {'CH', 'RER'}
    and act["unit"] == "kilometer"
]

pd.DataFrame(
    [
        {
            'name': act['name'],
            'location': act.get('location'),
            'unit': act.get('unit'),
        }
        for act in car_by_location[:15]
    ]
)
# Out:
#                                                                                                          name  \
# 0                                       Transport, passenger car, battery electric, LFP battery, Medium, 2021
# 1                                                 Transport, passenger car, gasoline, Large SUV, 2013, EURO-5
# 2                                           Transport, passenger car, compressed gas, Large SUV, 2003, EURO-3
# 3                                                    Operation, passenger car, methane, 96 vol-%, from biogas
# 4                                                   Transport, passenger car, gasoline, Large, 2016, EURO-6ab
# 5    Transport, passenger car, plugin gasoline hybrid, label-certified electricity, Large SUV, 2016, EURO-6ab
# 6                              Transport, passenger car, fuel cell electric, SMR of natural gas, Medium, 2021
# 7                                                     Transport, passenger car, compressed gas, fleet average
# 8                                                     Transport, passenger car, diesel, Medium, 2018, EURO-6c
# 9                            Transport, passenger car, plugin gasoline hybrid, UF=0%, Compact, 2016, EURO-6ab
# 10                                        Transport, passenger car, compressed gas, Large, 2019, EURO-6d-TEMP
# 11  Transport, passenger car, battery electric, NMC-622 battery, label-certified electricity, Large SUV, 2021
# 12                      Transport, passenger car, fuel cell electric, hydrogen from electrolysis, Large, 2021
# 13          Transport, passenger car, plugin diesel hybrid, label-certified electricity, Large, 2018, EURO-6c
# 14                                           Transport, passenger car, compressed gas, Compact, 2021, EURO-6d
#
#    location       unit
# 0        CH  kilometer
# 1        CH  kilometer
# 2        CH  kilometer
# 3        CH  kilometer
# 4       RER  kilometer
# 5        CH  kilometer
# 6        CH  kilometer
# 7        CH  kilometer
# 8       RER  kilometer
# 9        CH  kilometer
# 10       CH  kilometer
# 11       CH  kilometer
# 12       CH  kilometer
# 13       CH  kilometer
# 14       CH  kilometer

# %% [markdown]
# Let's choose one activity relating to driving a gasoline car and inspect its metadata and exchanges. Here we look at an `operation` activity, because it gives a nice mix of technosphere input(s) and biosphere emissions.

# %%
selected_activity = gasoline_car_candidates[0]

pprint(selected_activity.as_dict())
# Out:
# {'code': 'bafu-255560',
#  'comment': 'Driving cycle: WLTC. Combustion engine power: 76 [kW]. Power '
#             'share from combustion engine: 100 [%]. Km over lifetime: 200000 '
#             '[km]. Yearly mileage: 12000 [km/year]. Autonomy on a full '
#             'tank/battery: 874 [km]. Tank-to-wheel efficiency: 21 [%]. '
#             'Tank-to-wheel energy consumption: 1842 [kj/km]. Fuel tank '
#             'capacity: 447 [kWh]. Curb mass (excl. driver and cargo): 1177 '
#             '[kg]. Driving mass (incl. driver and cargo): 1317 [kg]..',
#  'database': 'bafu',
#  'filename': 'process_6129d7fe-06ad-3bca-ba6a-b1b34d1ea829.xml',
#  'id': 309634966968012800,
#  'location': 'RER',
#  'name': 'Transport, passenger car, gasoline, Compact, 2013, EURO-5',
#  'reference product': 'Transport, passenger car, gasoline, Compact, 2013, '
#                       'EURO-5',
#  'type': 'processwithreferenceproduct',
#  'unit': 'kilometer',
#  'worksheet name': 'bafu'}

# %% [markdown]
# Once you have one activity, you can iterate through its exchanges. Brightway lets you inspect `production()`, `technosphere()`, and `biosphere()` separately.

# %%
def preview_exchanges(exchanges, n=5):
    rows = []
    for exc in list(exchanges)[:n]:
        rows.append(
            {
                'input': exc.input['name'],
                'amount': exc['amount'],
                'unit': exc.input.get('unit'),
                'location': exc.input.get('location'),
                'categories': '::'.join(exc.input.get('categories') or ()),
                'type': exc['type'],
            }
        )
    return pd.DataFrame(rows)

print('Production exchanges')
display(preview_exchanges(selected_activity.production(), n=3))

print('Technosphere exchanges')
display(preview_exchanges(selected_activity.technosphere(), n=5))

print('Biosphere exchanges')
display(preview_exchanges(selected_activity.biosphere(), n=8))
# Out:
# Production exchanges
#                                                        input  amount  \
# 0  Transport, passenger car, gasoline, Compact, 2013, EURO-5       1
#
#         unit location categories        type
# 0  kilometer      RER             production
# Technosphere exchanges
#                                  input    amount        unit location  \
# 0  Brake wear emissions, passenger car  0.000013    kilogram      RER
# 1                       Disposal, road  0.000765  meter-year      RER
# 2    Fuel supply for gasoline vehicles  0.043900    kilogram      RER
# 3           Maintenance, passenger car  0.000006        unit      RER
# 4         Operation, maintenance, road  0.001290  meter-year       CH
#
#   categories          type
# 0             technosphere
# 1             technosphere
# 2             technosphere
# 3             technosphere
# 4             technosphere
# Biosphere exchanges
#           input        amount      unit location  \
# 0     1-Pentene  2.960000e-09  kilogram     None
# 1     1-Pentene  1.050000e-09  kilogram     None
# 2     1-Pentene  5.160000e-09  kilogram     None
# 3  Acetaldehyde  2.370000e-08  kilogram     None
# 4  Acetaldehyde  8.390000e-09  kilogram     None
# 5  Acetaldehyde  4.130000e-08  kilogram     None
# 6       Acetone  1.780000e-08  kilogram     None
# 7       Acetone  6.300000e-09  kilogram     None
#
#                                categories       type
# 0  air::non-urban air or from high stacks  biosphere
# 1  air::non-urban air or from high stacks  biosphere
# 2          air::urban air close to ground  biosphere
# 3  air::non-urban air or from high stacks  biosphere
# 4  air::non-urban air or from high stacks  biosphere
# 5          air::urban air close to ground  biosphere
# 6  air::non-urban air or from high stacks  biosphere
# 7  air::non-urban air or from high stacks  biosphere

# %% [markdown]
# You can use the same idea for any activity attributes (classifications, authors, year of publication), provided those are filled in.

# %% [markdown]
# ## Checkpoint 1
#
# Pick one activity from the imported database, store it in `selected_activity`, and inspect a few production, technosphere, and biosphere exchanges.
#
# Suggestion: start with a gasoline passenger car activity and refine by `location` if you get too many hits.

# %%
# TODO
# Example pattern:
# hits = [
#     act for act in db
#     if 'passenger car' in act['name'].lower()
#     and any(term in act['name'].lower() for term in ['gasoline', 'petrol'])
# ]
# selected_activity = hits[0]
# preview_exchanges(selected_activity.technosphere(), n=3)
# preview_exchanges(selected_activity.biosphere(), n=3)

# %%
db = bd.Database("bafu")
hits = [
    act
    for act in db
    if 'passenger car' in act['name'].lower()
    and any(term in act['name'].lower() for term in ['gasoline', 'petrol'])
    and 'operation' in act['name'].lower()
]

selected_activity = hits[0] if hits else db.random()

print('Selected activity:', selected_activity['name'])
print('Location:', selected_activity.get('location'))
print('Unit:', selected_activity.get('unit'))

print('First production exchanges:')
display(preview_exchanges(selected_activity.production(), n=3))

print('First technosphere exchanges:')
display(preview_exchanges(selected_activity.technosphere(), n=3))

print('First biosphere exchanges:')
display(preview_exchanges(selected_activity.biosphere(), n=5))
# Out:
# Selected activity: Operation, passenger car, petrol, 15% vol. ETBE with ethanol from biomass, EURO4
# Location: CH
# Unit: kilometer
# First production exchanges:
#                                                                               input  \
# 0  Operation, passenger car, petrol, 15% vol. ETBE with ethanol from biomass, EURO4
#
#    amount       unit location categories        type
# 0       1  kilometer       CH             production
# First technosphere exchanges:
#                                                                             input  \
# 0  Petrol, 15% vol. ETBE additive, EtOH f. biomass, prod. RER, at service station
#
#      amount      unit location categories          type
# 0  0.060379  kilogram       CH             technosphere
# First biosphere exchanges:
#         input        amount      unit location categories       type
# 0     Ammonia  2.306700e-05  kilogram     None        air  biosphere
# 1     Benzene  8.891500e-06  kilogram     None        air  biosphere
# 2  Cadmium II  1.242200e-09  kilogram     None        air  biosphere
# 3  Cadmium II  9.550000e-11  kilogram     None       soil  biosphere
# 4  Cadmium II  9.550000e-11  kilogram     None      water  biosphere

# %% [markdown]
# ## Checkpoint 2
#
# Choose one of the LCIA methods already available in the installed project, ideally the climate-change indicator, and store it in `selected_method`.

# %%
# TODO
# Example pattern:
# [m for m in bd.methods if 'climate change' in ' | '.join(m).lower()][:5]
# selected_method = ...

# %%
preferred_method = ('EF v3.1', 'climate change', 'global warming potential (GWP100)')

if preferred_method in bd.methods:
    selected_method = preferred_method
else:
    climate_methods = [m for m in bd.methods if 'climate change' in ' | '.join(m).lower()]
    selected_method = climate_methods[0] if climate_methods else next(iter(bd.methods))

print('Selected method:', selected_method)
print('Method unit:', bd.Method(selected_method).metadata.get('unit'))
# Out:
# Selected method: ('EF v3.1', 'climate change', 'global warming potential (GWP100)')
# Method unit: kg CO2-Eq

# %% [markdown]
# ## 7) Run your first LCA and inspect the matrices
#
# We now combine the selected activity and method into a complete LCA calculation, and then look at the matrix objects that Brightway builds behind the scenes.

# %%
method = ('EF v3.1', 'climate change', 'global warming potential (GWP100)')

# bw2calc.LCA is the LCA calculation engine of `bw2calc`
# it expect a functional unit demand, and an LCIA method (optional)
lca = bc.LCA({selected_activity: 1}, selected_method)

# here, we solve the system (As=f) and obtain the inventory
lca.lci()

# and we multiply the inventory by the characterization matrix
lca.lcia()

print('Activity:', selected_activity['name'])
print('Method:', selected_method)
print('LCA score:', lca.score)
# Out:
# Activity: Operation, passenger car, petrol, 15% vol. ETBE with ethanol from biomass, EURO4
# Method: ('EF v3.1', 'climate change', 'global warming potential (GWP100)')
# LCA score: 0.2416033568295284

# %% [markdown]
# ### 7.1 From the demand dict to the demand array
#
# The argument passed to `bc.LCA(...)` is a Python dictionary: it is easy to read, but not yet in matrix form.
# After `lca.lci()`, Brightway has translated this demand into a numerical vector in product space: `lca.demand_array`.

# %%
print('Demand dict:')
print(lca.demand)
print()
print('Demand array shape:', lca.demand_array.shape)
print('Number of non-zero entries in demand_array:', np.count_nonzero(lca.demand_array))
# Out:
# Demand dict:
# {309634940585840640: 1}
#
# Demand array shape: (11747,)
# Number of non-zero entries in demand_array: 1

# %%
demand_id = list(lca.demand.keys())[0]
demand_id
# Out:
# 309634940585840640

# %%
# where is that demand in the demand vector?
demand_index = int(np.flatnonzero(lca.demand_array)[0])
demand_index
# Out:
# 6885

# %%
# we have some reversed dictionaries that can 
# help us map indices (meaning position in a vector or matrix) to IDs
lca.dicts.product.reversed
# Out:
# {0: 309634890161917952,
#  1: 309634890161917953,
#  2: 309634890161917954,
#  3: 309634890161917955,
#  4: 309634890161917956,
#  5: 309634890161917957,
#  6: 309634890161917958,
#  7: 309634890161917959,
#  8: 309634890191278080,
#  9: 309634890191278081,
#  10: 309634890191278082,
#  11: 309634890191278083,
#  12: 309634890191278084,
#  13: 309634890191278085,
#  14: 309634890216443904,
#  15: 309634890216443905,
#  16: 309634890216443906,
#  17: 309634890216443907,
#  18: 309634890216443908,
#  19: 309634890216443909,
#  20: 309634890216443910,
#  21: 309634890216443911,
#  22: 309634890216443912,
#  23: 309634890216443913,
#  24: 309634890216443914,
#  25: 309634890216443915,
#  26: 309634890216443916,
#  27: 309634890237415424,
#  28: 309634890237415425,
#  29: 309634890237415426,
#  30: 309634890237415427,
#  31: 309634890237415428,
#  32: 309634890237415429,
#  33: 309634890237415430,
#  34: 309634890237415431,
#  35: 309634890237415432,
#  36: 309634890237415433,
#  37: 309634890237415434,
#  38: 309634890237415435,
#  39: 309634890237415436,
#  40: 309634890237415437,
#  41: 309634890262581248,
#  42: 309634890262581249,
#  43: 309634890262581250,
#  44: 309634890262581251,
#  45: 309634890262581252,
#  46: 309634890262581253,
#  47: 309634890262581254,
#  48: 309634890262581255,
#  49: 309634890262581256,
#  50: 309634890262581257,
#  51: 309634890262581258,
#  52: 309634890262581259,
#  53: 309634890262581260,
#  54: 309634890300329984,
#  55: 309634890300329985,
#  56: 309634890300329986,
#  57: 309634890300329987,
#  58: 309634890300329988,
#  59: 309634890300329989,
#  60: 309634890300329990,
#  61: 309634890300329991,
#  62: 309634890300329992,
#  63: 309634890300329993,
#  64: 309634890300329994,
#  65: 309634890300329995,
#  66: 309634890300329996,
#  67: 309634890300329997,
#  68: 309634890329690112,
#  69: 309634890329690113,
#  70: 309634890329690114,
#  71: 309634890329690115,
#  72: 309634890329690116,
#  73: 309634890329690117,
#  74: 309634890329690118,
#  75: 309634890329690119,
#  76: 309634890329690120,
#  77: 309634890329690121,
#  78: 309634890329690122,
#  79: 309634890329690123,
#  80: 309634890329690124,
#  81: 309634890329690125,
#  82: 309634890359050240,
#  83: 309634890359050241,
#  84: 309634890359050242,
#  85: 309634890359050243,
#  86: 309634890359050244,
#  87: 309634890359050245,
#  88: 309634890359050246,
#  89: 309634890359050247,
#  90: 309634890359050248,
#  91: 309634890359050249,
#  92: 309634890359050250,
#  93: 309634890359050251,
#  94: 309634890388410368,
#  95: 309634890392604672,
#  96: 309634890417770496,
#  97: 309634890417770497,
#  98: 309634890417770498,
#  99: 309634890447130624,
#  100: 309634890447130625,
#  101: 309634890447130626,
#  102: 309634890476490752,
#  103: 309634890476490753,
#  104: 309634890476490754,
#  105: 309634890476490755,
#  106: 309634890505850880,
#  107: 309634890505850881,
#  108: 309634890505850882,
#  109: 309634890505850883,
#  110: 309634890510045184,
#  111: 309634890510045185,
#  112: 309634890510045186,
#  113: 309634890510045187,
#  114: 309634890510045188,
#  115: 309634890556182528,
#  116: 309634890556182529,
#  117: 309634890560376832,
#  118: 309634890560376833,
#  119: 309634890560376834,
#  120: 309634890560376835,
#  121: 309634890560376836,
#  122: 309634890560376837,
#  123: 309634890560376838,
#  124: 309634890560376839,
#  125: 309634890560376840,
#  126: 309634890623291392,
#  127: 309634890623291393,
#  128: 309634890623291394,
#  129: 309634890623291395,
#  130: 309634890623291396,
#  131: 309634890623291397,
#  132: 309634890623291398,
#  133: 309634890623291399,
#  134: 309634890623291400,
#  135: 309634890648457216,
#  136: 309634890648457217,
#  137: 309634890648457218,
#  138: 309634890677817344,
#  139: 309634890677817345,
#  140: 309634890677817346,
#  141: 309634890707177472,
#  142: 309634890707177473,
#  143: 309634890707177474,
#  144: 309634890707177475,
#  145: 309634890707177476,
#  146: 309634890707177477,
#  147: 309634890736537600,
#  148: 309634890736537601,
#  149: 309634890736537602,
#  150: 309634890736537603,
#  151: 309634890736537604,
#  152: 309634890736537605,
#  153: 309634890736537606,
#  154: 309634890736537607,
#  155: 309634890736537608,
#  156: 309634890736537609,
#  157: 309634890736537610,
#  158: 309634890736537611,
#  159: 309634890736537612,
#  160: 309634890736537613,
#  161: 309634890736537614,
#  162: 309634890736537615,
#  163: 309634890765897728,
#  164: 309634890765897729,
#  165: 309634890765897730,
#  166: 309634890765897731,
#  167: 309634890765897732,
#  168: 309634890765897733,
#  169: 309634890765897734,
#  170: 309634890765897735,
#  171: 309634891093053440,
#  172: 309634891093053441,
#  173: 309634891093053442,
#  174: 309634891093053443,
#  175: 309634891093053444,
#  176: 309634891093053445,
#  177: 309634891093053446,
#  178: 309634891114024960,
#  179: 309634891114024961,
#  180: 309634891114024962,
#  181: 309634891114024963,
#  182: 309634891114024964,
#  183: 309634891114024965,
#  184: 309634891114024966,
#  185: 309634891114024967,
#  186: 309634891114024968,
#  187: 309634891114024969,
#  188: 309634891114024970,
#  189: 309634891143385088,
#  190: 309634891143385089,
#  191: 309634891143385090,
#  192: 309634891143385091,
#  193: 309634891143385092,
#  194: 309634891143385093,
#  195: 309634891143385094,
#  196: 309634891143385095,
#  197: 309634891143385096,
#  198: 309634891143385097,
#  199: 309634891172745216,
#  200: 309634891172745217,
#  201: 309634891172745218,
#  202: 309634891172745219,
#  203: 309634891202105344,
#  204: 309634891202105345,
#  205: 309634891202105346,
#  206: 309634891202105347,
#  207: 309634891202105348,
#  208: 309634891202105349,
#  209: 309634891202105350,
#  210: 309634891202105351,
#  211: 309634891231465472,
#  212: 309634891231465473,
#  213: 309634891231465474,
#  214: 309634891231465475,
#  215: 309634891231465476,
#  216: 309634891231465477,
#  217: 309634891231465478,
#  218: 309634891231465479,
#  219: 309634891231465480,
#  220: 309634891231465481,
#  221: 309634891231465482,
#  222: 309634891260825600,
#  223: 309634891260825601,
#  224: 309634891260825602,
#  225: 309634891260825603,
#  226: 309634891260825604,
#  227: 309634891260825605,
#  228: 309634891260825606,
#  229: 309634891260825607,
#  230: 309634891260825608,
#  231: 309634891260825609,
#  232: 309634891260825610,
#  233: 309634891260825611,
#  234: 309634891260825612,
#  235: 309634891290185728,
#  236: 309634891290185729,
#  237: 309634891290185730,
#  238: 309634891290185731,
#  239: 309634891290185732,
#  240: 309634891319545856,
#  241: 309634891340517376,
#  242: 309634891919331328,
#  243: 309634891919331329,
#  244: 309634891919331330,
#  245: 309634891919331331,
#  246: 309634891919331332,
#  247: 309634891919331333,
#  248: 309634891919331334,
#  249: 309634891948691456,
#  250: 309634891952885760,
#  251: 309634891952885761,
#  252: 309634891982245888,
#  253: 309634891982245889,
#  254: 309634891982245890,
#  255: 309634891982245891,
#  256: 309634891982245892,
#  257: 309634891982245893,
#  258: 309634892011606016,
#  259: 309634892011606017,
#  260: 309634892011606018,
#  261: 309634892040966144,
#  262: 309634892372316160,
#  263: 309634892372316161,
#  264: 309634892372316162,
#  265: 309634892418453504,
#  266: 309634892418453505,
#  267: 309634892418453506,
#  268: 309634892418453507,
#  269: 309634892418453508,
#  270: 309634892418453509,
#  271: 309634892418453510,
#  272: 309634892418453511,
#  273: 309634892418453512,
#  274: 309634892418453513,
#  275: 309634892418453514,
#  276: 309634892418453515,
#  277: 309634892418453516,
#  278: 309634892418453517,
#  279: 309634892418453518,
#  280: 309634892418453519,
#  281: 309634892485562368,
#  282: 309634892506533888,
#  283: 309634892506533889,
#  284: 309634892506533890,
#  285: 309634892506533891,
#  286: 309634892506533892,
#  287: 309634892506533893,
#  288: 309634892506533894,
#  289: 309634892510728192,
#  290: 309634892510728193,
#  291: 309634892510728194,
#  292: 309634892510728195,
#  293: 309634892510728196,
#  294: 309634892510728197,
#  295: 309634892510728198,
#  296: 309634892561059840,
#  297: 309634892561059841,
#  298: 309634892561059842,
#  299: 309634892561059843,
#  300: 309634892561059844,
#  301: 309634892561059845,
#  302: 309634892561059846,
#  303: 309634892561059847,
#  304: 309634892561059848,
#  305: 309634892561059849,
#  306: 309634892561059850,
#  307: 309634892636557312,
#  308: 309634892657528832,
#  309: 309634892657528833,
#  310: 309634893026627584,
#  311: 309634893026627585,
#  312: 309634893026627586,
#  313: 309634893026627587,
#  314: 309634893026627588,
#  315: 309634893026627589,
#  316: 309634893055987712,
#  317: 309634893055987713,
#  318: 309634893055987714,
#  319: 309634893055987715,
#  320: 309634893055987716,
#  321: 309634893055987717,
#  322: 309634893055987718,
#  323: 309634893055987719,
#  324: 309634893060182016,
#  325: 309634893060182017,
#  326: 309634893060182018,
#  327: 309634893081153536,
#  328: 309634893081153537,
#  329: 309634893081153538,
#  330: 309634893081153539,
#  331: 309634893081153540,
#  332: 309634893110513664,
#  333: 309634893110513665,
#  334: 309634893110513666,
#  335: 309634893110513667,
#  336: 309634893110513668,
#  337: 309634893110513669,
#  338: 309634893139873792,
#  339: 309634893173428224,
#  340: 309634893202788352,
#  341: 309634893202788353,
#  342: 309634893202788354,
#  343: 309634893253120000,
#  344: 309634893269897216,
#  345: 309634893269897217,
#  346: 309634893299257344,
#  347: 309634893299257345,
#  348: 309634893299257346,
#  349: 309634893299257347,
#  350: 309634893299257348,
#  351: 309634893299257349,
#  352: 309634893299257350,
#  353: 309634893299257351,
#  354: 309634893299257352,
#  355: 309634893299257353,
#  356: 309634893299257354,
#  357: 309634893328617472,
#  358: 309634893328617473,
#  359: 309634893328617474,
#  360: 309634893328617475,
#  361: 309634893328617476,
#  362: 309634893328617477,
#  363: 309634893328617478,
#  364: 309634893328617479,
#  365: 309634893328617480,
#  366: 309634893328617481,
#  367: 309634893328617482,
#  368: 309634893362171904,
#  369: 309634893362171905,
#  370: 309634893362171906,
#  371: 309634893362171907,
#  372: 309634893362171908,
#  373: 309634893362171909,
#  374: 309634893362171910,
#  375: 309634893362171911,
#  376: 309634893362171912,
#  377: 309634893362171913,
#  378: 309634893404114944,
#  379: 309634893433475072,
#  380: 309634893433475073,
#  381: 309634893433475074,
#  382: 309634893433475075,
#  383: 309634893433475076,
#  384: 309634893433475077,
#  385: 309634893433475078,
#  386: 309634893433475079,
#  387: 309634893433475080,
#  388: 309634893433475081,
#  389: 309634893467029504,
#  390: 309634893467029505,
#  391: 309634893467029506,
#  392: 309634893467029507,
#  393: 309634893467029508,
#  394: 309634893467029509,
#  395: 309634893467029510,
#  396: 309634893467029511,
#  397: 309634893467029512,
#  398: 309634893492195328,
#  399: 309634893496389632,
#  400: 309634893496389633,
#  401: 309634893496389634,
#  402: 309634893521555456,
#  403: 309634893521555457,
#  404: 309634893521555458,
#  405: 309634893521555459,
#  406: 309634893542526976,
#  407: 309634893542526977,
#  408: 309634893571887104,
#  409: 309634893605441536,
#  410: 309634893634801664,
#  411: 309634893634801665,
#  412: 309634893634801666,
#  413: 309634893634801667,
#  414: 309634893634801668,
#  415: 309634893634801669,
#  416: 309634893634801670,
#  417: 309634893668356096,
#  418: 309634893697716224,
#  419: 309634893697716225,
#  420: 309634893731270656,
#  421: 309634893731270657,
#  422: 309634893731270658,
#  423: 309634893731270659,
#  424: 309634893731270660,
#  425: 309634893731270661,
#  426: 309634893731270662,
#  427: 309634893731270663,
#  428: 309634893756436480,
#  429: 309634893756436481,
#  430: 309634893756436482,
#  431: 309634893756436483,
#  432: 309634893756436484,
#  433: 309634893756436485,
#  434: 309634893756436486,
#  435: 309634893756436487,
#  436: 309634893756436488,
#  437: 309634893756436489,
#  438: 309634893756436490,
#  439: 309634893756436491,
#  440: 309634893777408000,
#  441: 309634893777408001,
#  442: 309634893777408002,
#  443: 309634893777408003,
#  444: 309634893777408004,
#  445: 309634893777408005,
#  446: 309634893777408006,
#  447: 309634893777408007,
#  448: 309634893802573824,
#  449: 309634894142312448,
#  450: 309634894142312449,
#  451: 309634894142312450,
#  452: 309634894523994112,
#  453: 309634894523994113,
#  454: 309634894523994114,
#  455: 309634894523994115,
#  456: 309634894523994116,
#  457: 309634894523994117,
#  458: 309634894549159936,
#  459: 309634894549159937,
#  460: 309634894553354240,
#  461: 309634894553354241,
#  462: 309634894553354242,
#  463: 309634894553354243,
#  464: 309634894553354244,
#  465: 309634894578520064,
#  466: 309634894582714368,
#  467: 309634894964396032,
#  468: 309634894964396033,
#  469: 309634894989561856,
#  470: 309634895018921984,
#  471: 309634895052476416,
#  472: 309634895052476417,
#  473: 309634895052476418,
#  474: 309634895052476419,
#  475: 309634895081836544,
#  476: 309634895081836545,
#  477: 309634895081836546,
#  478: 309634895081836547,
#  479: 309634895081836548,
#  480: 309634895081836549,
#  481: 309634895081836550,
#  482: 309634895081836551,
#  483: 309634895081836552,
#  484: 309634895081836553,
#  485: 309634895081836554,
#  486: 309634895115390976,
#  487: 309634895115390977,
#  488: 309634895115390978,
#  489: 309634895115390979,
#  490: 309634895140556800,
#  491: 309634895140556801,
#  492: 309634895140556802,
#  493: 309634895140556803,
#  494: 309634895140556804,
#  495: 309634895140556805,
#  496: 309634895161528320,
#  497: 309634895161528321,
#  498: 309634895161528322,
#  499: 309634895161528323,
#  500: 309634895161528324,
#  501: 309634895161528325,
#  502: 309634895186694144,
#  503: 309634895186694145,
#  504: 309634895224442880,
#  505: 309634895224442881,
#  506: 309634895224442882,
#  507: 309634895224442883,
#  508: 309634895228637184,
#  509: 309634895228637185,
#  510: 309634895228637186,
#  511: 309634895228637187,
#  512: 309634895228637188,
#  513: 309634895228637189,
#  514: 309634895253803008,
#  515: 309634895253803009,
#  516: 309634895253803010,
#  517: 309634895253803011,
#  518: 309634895253803012,
#  519: 309634895253803013,
#  520: 309634895253803014,
#  521: 309634895253803015,
#  522: 309634895253803016,
#  523: 309634895253803017,
#  524: 309634895283163136,
#  525: 309634895283163137,
#  526: 309634895283163138,
#  527: 309634895283163139,
#  528: 309634895283163140,
#  529: 309634895283163141,
#  530: 309634895283163142,
#  531: 309634895283163143,
#  532: 309634895283163144,
#  533: 309634895316717568,
#  534: 309634895316717569,
#  535: 309634895316717570,
#  536: 309634895316717571,
#  537: 309634895316717572,
#  538: 309634895316717573,
#  539: 309634895316717574,
#  540: 309634895316717575,
#  541: 309634895316717576,
#  542: 309634895316717577,
#  543: 309634895316717578,
#  544: 309634895341883392,
#  545: 309634895341883393,
#  546: 309634895341883394,
#  547: 309634895341883395,
#  548: 309634895341883396,
#  549: 309634895341883397,
#  550: 309634895341883398,
#  551: 309634895362854912,
#  552: 309634895627096064,
#  553: 309634895627096065,
#  554: 309634895627096066,
#  555: 309634895627096067,
#  556: 309634895627096068,
#  557: 309634895627096069,
#  558: 309634895627096070,
#  559: 309634895652261888,
#  560: 309634895656456192,
#  561: 309634895656456193,
#  562: 309634895656456194,
#  563: 309634895656456195,
#  564: 309634895656456196,
#  565: 309634895656456197,
#  566: 309634895656456198,
#  567: 309634895656456199,
#  568: 309634895656456200,
#  569: 309634895656456201,
#  570: 309634895656456202,
#  571: 309634895656456203,
#  572: 309634895656456204,
#  573: 309634895656456205,
#  574: 309634895681622016,
#  575: 309634895681622017,
#  576: 309634895681622018,
#  577: 309634895698399232,
#  578: 309634895698399233,
#  579: 309634895698399234,
#  580: 309634895698399235,
#  581: 309634895996194816,
#  582: 309634896306573312,
#  583: 309634896608563200,
#  584: 309634896608563201,
#  585: 309634896608563202,
#  586: 309634896608563203,
#  587: 309634896935718912,
#  588: 309634896935718913,
#  589: 309634896935718914,
#  590: 309634896935718915,
#  591: 309634896935718916,
#  592: 309634896935718917,
#  593: 309634896935718918,
#  594: 309634896935718919,
#  595: 309634896935718920,
#  596: 309634896935718921,
#  597: 309634896935718922,
#  598: 309634896935718923,
#  599: 309634896965079040,
#  600: 309634896965079041,
#  601: 309634896965079042,
#  602: 309634896965079043,
#  603: 309634896965079044,
#  604: 309634896990244864,
#  605: 309634896994439168,
#  606: 309634896994439169,
#  607: 309634896994439170,
#  608: 309634896994439171,
#  609: 309634896994439172,
#  610: 309634896994439173,
#  611: 309634896994439174,
#  612: 309634896994439175,
#  613: 309634896994439176,
#  614: 309634897027993600,
#  615: 309634897027993601,
#  616: 309634897027993602,
#  617: 309634897027993603,
#  618: 309634897027993604,
#  619: 309634897027993605,
#  620: 309634897027993606,
#  621: 309634897057353728,
#  622: 309634897057353729,
#  623: 309634897057353730,
#  624: 309634897057353731,
#  625: 309634897057353732,
#  626: 309634897086713856,
#  627: 309634897086713857,
#  628: 309634897086713858,
#  629: 309634897086713859,
#  630: 309634897124462592,
#  631: 309634897124462593,
#  632: 309634897124462594,
#  633: 309634897124462595,
#  634: 309634897124462596,
#  635: 309634897124462597,
#  636: 309634897124462598,
#  637: 309634897124462599,
#  638: 309634897124462600,
#  639: 309634897124462601,
#  640: 309634897124462602,
#  641: 309634897124462603,
#  642: 309634897153822720,
#  643: 309634897153822721,
#  644: 309634897153822722,
#  645: 309634897153822723,
#  646: 309634897153822724,
#  647: 309634897153822725,
#  648: 309634897153822726,
#  649: 309634897153822727,
#  650: 309634897153822728,
#  651: 309634897153822729,
#  652: 309634897153822730,
#  653: 309634897153822731,
#  654: 309634897153822732,
#  655: 309634897153822733,
#  656: 309634897153822734,
#  657: 309634897153822735,
#  658: 309634897153822736,
#  659: 309634897183182848,
#  660: 309634897183182849,
#  661: 309634897183182850,
#  662: 309634897183182851,
#  663: 309634897183182852,
#  664: 309634897183182853,
#  665: 309634897183182854,
#  666: 309634897183182855,
#  667: 309634897212542976,
#  668: 309634897212542977,
#  669: 309634897212542978,
#  670: 309634897212542979,
#  671: 309634897212542980,
#  672: 309634897237708800,
#  673: 309634897237708801,
#  674: 309634897237708802,
#  675: 309634897237708803,
#  676: 309634897237708804,
#  677: 309634897237708805,
#  678: 309634897237708806,
#  679: 309634897254486016,
#  680: 309634897254486017,
#  681: 309634897254486018,
#  682: 309634897254486019,
#  683: 309634897279651840,
#  684: 309634897279651841,
#  685: 309634897309011968,
#  686: 309634897309011969,
#  687: 309634897309011970,
#  688: 309634897309011971,
#  689: 309634897309011972,
#  690: 309634897309011973,
#  691: 309634897309011974,
#  692: 309634897309011975,
#  693: 309634897309011976,
#  694: 309634897309011977,
#  695: 309634897309011978,
#  696: 309634897334177792,
#  697: 309634897334177793,
#  698: 309634897334177794,
#  699: 309634897334177795,
#  700: 309634897334177796,
#  701: 309634897334177797,
#  702: 309634897334177798,
#  703: 309634897334177799,
#  704: 309634897334177800,
#  705: 309634897334177801,
#  706: 309634897334177802,
#  707: 309634897334177803,
#  708: 309634897334177804,
#  709: 309634897334177805,
#  710: 309634897363537920,
#  711: 309634897363537921,
#  712: 309634897363537922,
#  713: 309634897363537923,
#  714: 309634897363537924,
#  715: 309634897384509440,
#  716: 309634897384509441,
#  717: 309634897384509442,
#  718: 309634897384509443,
#  719: 309634897384509444,
#  720: 309634897384509445,
#  721: 309634897384509446,
#  722: 309634897384509447,
#  723: 309634897384509448,
#  724: 309634897384509449,
#  725: 309634897384509450,
#  726: 309634897384509451,
#  727: 309634897384509452,
#  728: 309634897384509453,
#  729: 309634897384509454,
#  730: 309634897384509455,
#  731: 309634897405480960,
#  732: 309634897405480961,
#  733: 309634897405480962,
#  734: 309634897405480963,
#  735: 309634897405480964,
#  736: 309634897405480965,
#  737: 309634897405480966,
#  738: 309634897405480967,
#  739: 309634897405480968,
#  740: 309634897405480969,
#  741: 309634897405480970,
#  742: 309634897426452480,
#  743: 309634897430646784,
#  744: 309634897430646785,
#  745: 309634897430646786,
#  746: 309634897430646787,
#  747: 309634897430646788,
#  748: 309634897430646789,
#  749: 309634897455812608,
#  750: 309634897455812609,
#  751: 309634897455812610,
#  752: 309634897455812611,
#  753: 309634897455812612,
#  754: 309634897455812613,
#  755: 309634897455812614,
#  756: 309634897514532864,
#  757: 309634897514532865,
#  758: 309634897514532866,
#  759: 309634897514532867,
#  760: 309634897514532868,
#  761: 309634897514532869,
#  762: 309634897514532870,
#  763: 309634897543892992,
#  764: 309634897543892993,
#  765: 309634897543892994,
#  766: 309634897543892995,
#  767: 309634897543892996,
#  768: 309634897543892997,
#  769: 309634897577447424,
#  770: 309634897577447425,
#  771: 309634897577447426,
#  772: 309634897577447427,
#  773: 309634897577447428,
#  774: 309634897577447429,
#  775: 309634897577447430,
#  776: 309634897606807552,
#  777: 309634897606807553,
#  778: 309634897606807554,
#  779: 309634897606807555,
#  780: 309634897606807556,
#  781: 309634897606807557,
#  782: 309634897636167680,
#  783: 309634897636167681,
#  784: 309634897636167682,
#  785: 309634897636167683,
#  786: 309634897636167684,
#  787: 309634897636167685,
#  788: 309634897636167686,
#  789: 309634897636167687,
#  790: 309634897636167688,
#  791: 309634897636167689,
#  792: 309634897636167690,
#  793: 309634897636167691,
#  794: 309634897636167692,
#  795: 309634897665527808,
#  796: 309634897665527809,
#  797: 309634897665527810,
#  798: 309634897665527811,
#  799: 309634897665527812,
#  800: 309634897665527813,
#  801: 309634897665527814,
#  802: 309634897665527815,
#  803: 309634897665527816,
#  804: 309634897665527817,
#  805: 309634897665527818,
#  806: 309634897665527819,
#  807: 309634897665527820,
#  808: 309634897694887936,
#  809: 309634897694887937,
#  810: 309634897694887938,
#  811: 309634897694887939,
#  812: 309634897694887940,
#  813: 309634897694887941,
#  814: 309634897694887942,
#  815: 309634897724248064,
#  816: 309634897724248065,
#  817: 309634897724248066,
#  818: 309634897724248067,
#  819: 309634897724248068,
#  820: 309634897724248069,
#  821: 309634897724248070,
#  822: 309634897724248071,
#  823: 309634897753608192,
#  824: 309634897753608193,
#  825: 309634897753608194,
#  826: 309634897753608195,
#  827: 309634897757802496,
#  828: 309634897787162624,
#  829: 309634897787162625,
#  830: 309634897816522752,
#  831: 309634897816522753,
#  832: 309634897845882880,
#  833: 309634897845882881,
#  834: 309634897845882882,
#  835: 309634897845882883,
#  836: 309634897845882884,
#  837: 309634897845882885,
#  838: 309634897845882886,
#  839: 309634897845882887,
#  840: 309634897845882888,
#  841: 309634897845882889,
#  842: 309634897871048704,
#  843: 309634897875243008,
#  844: 309634897875243009,
#  845: 309634897875243010,
#  846: 309634897875243011,
#  847: 309634897875243012,
#  848: 309634897896214528,
#  849: 309634897896214529,
#  850: 309634897917186048,
#  851: 309634897917186049,
#  852: 309634897917186050,
#  853: 309634897942351872,
#  854: 309634897942351873,
#  855: 309634897942351874,
#  856: 309634897942351875,
#  857: 309634897942351876,
#  858: 309634897971712000,
#  859: 309634898361782272,
#  860: 309634898391142400,
#  861: 309634898412113920,
#  862: 309634898433085440,
#  863: 309634898454056960,
#  864: 309634898454056961,
#  865: 309634898475028480,
#  866: 309634898475028481,
#  867: 309634898496000000,
#  868: 309634898516971520,
#  869: 309634898542137344,
#  870: 309634898542137345,
#  871: 309634898542137346,
#  872: 309634898542137347,
#  873: 309634898542137348,
#  874: 309634898915430400,
#  875: 309634899204837376,
#  876: 309634899225808896,
#  877: 309634899225808897,
#  878: 309634899225808898,
#  879: 309634899225808899,
#  880: 309634899225808900,
#  881: 309634899225808901,
#  882: 309634899255169024,
#  883: 309634899255169025,
#  884: 309634899259363328,
#  885: 309634899259363329,
#  886: 309634899259363330,
#  887: 309634899259363331,
#  888: 309634899259363332,
#  889: 309634899259363333,
#  890: 309634899259363334,
#  891: 309634899259363335,
#  892: 309634899259363336,
#  893: 309634899259363337,
#  894: 309634899259363338,
#  895: 309634899259363339,
#  896: 309634899259363340,
#  897: 309634899259363341,
#  898: 309634899259363342,
#  899: 309634899259363343,
#  900: 309634899259363344,
#  901: 309634899259363345,
#  902: 309634899284529152,
#  903: 309634899284529153,
#  904: 309634899284529154,
#  905: 309634899284529155,
#  906: 309634899284529156,
#  907: 309634899284529157,
#  908: 309634899284529158,
#  909: 309634899284529159,
#  910: 309634899284529160,
#  911: 309634899284529161,
#  912: 309634899284529162,
#  913: 309634899284529163,
#  914: 309634899284529164,
#  915: 309634899284529165,
#  916: 309634899284529166,
#  917: 309634899284529167,
#  918: 309634899288723456,
#  919: 309634899288723457,
#  920: 309634899288723458,
#  921: 309634899288723459,
#  922: 309634899288723460,
#  923: 309634899288723461,
#  924: 309634899288723462,
#  925: 309634899288723463,
#  926: 309634899288723464,
#  927: 309634899288723465,
#  928: 309634899292917760,
#  929: 309634899322277888,
#  930: 309634899322277889,
#  931: 309634899322277890,
#  932: 309634899322277891,
#  933: 309634899355832320,
#  934: 309634899355832321,
#  935: 309634899355832322,
#  936: 309634899355832323,
#  937: 309634899355832324,
#  938: 309634899389386752,
#  939: 309634899389386753,
#  940: 309634899389386754,
#  941: 309634899389386755,
#  942: 309634899418746880,
#  943: 309634899418746881,
#  944: 309634899418746882,
#  945: 309634899418746883,
#  946: 309634899448107008,
#  947: 309634899448107009,
#  948: 309634899448107010,
#  949: 309634899448107011,
#  950: 309634899481661440,
#  951: 309634899481661441,
#  952: 309634899481661442,
#  953: 309634899481661443,
#  954: 309634899481661444,
#  955: 309634899515215872,
#  956: 309634899515215873,
#  957: 309634899515215874,
#  958: 309634899515215875,
#  959: 309634899536187392,
#  960: 309634899536187393,
#  961: 309634899536187394,
#  962: 309634899536187395,
#  963: 309634899552964608,
#  964: 309634899552964609,
#  965: 309634899552964610,
#  966: 309634899552964611,
#  967: 309634899573936128,
#  968: 309634899573936129,
#  969: 309634899573936130,
#  970: 309634899573936131,
#  971: 309634899573936132,
#  972: 309634899573936133,
#  973: 309634899573936134,
#  974: 309634899573936135,
#  975: 309634899573936136,
#  976: 309634899620073472,
#  977: 309634899620073473,
#  978: 309634899620073474,
#  979: 309634899620073475,
#  980: 309634899620073476,
#  981: 309634899620073477,
#  982: 309634899620073478,
#  983: 309634899620073479,
#  984: 309634899699765248,
#  985: 309634899699765249,
#  986: 309634899699765250,
#  987: 309634899699765251,
#  988: 309634899729125376,
#  989: 309634899737513984,
#  990: 309634899737513985,
#  991: 309634899737513986,
#  992: 309634899758485504,
#  993: 309634899758485505,
#  994: 309634899758485506,
#  995: 309634899758485507,
#  996: 309634899783651328,
#  997: 309634899783651329,
#  998: 309634899783651330,
#  999: 309634899783651331,
#  ...}

# %%
# let's check: is the position of our demand in the demand vector 
# leads to the ID we fetched from `lca.demand`?
lca.dicts.product.reversed[demand_index] == demand_id
# Cool!
# Out:
# True

# %%
# hence, we now know who the functional unit is...
demanded_product = bd.get_activity(demand_id)
pd.Series(
    {
        'demanded product index': demand_index,
        'demanded product': demanded_product['name'],
        'location': demanded_product.get('location'),
        'amount in demand_array': lca.demand_array[demand_index],
    }
)
# Out:
# demanded product index                                                                                6885
# demanded product          Operation, passenger car, petrol, 15% vol. ETBE with ethanol from biomass, EURO4
# location                                                                                                CH
# amount in demand_array                                                                                 1.0
# dtype: object

# %% [markdown]
# Mapping dicitonaries and their reversed forms are available for **products**, **activities** and **biosphere flows**.
# They allow us to know who is behind a specific position in a specific vector or matrix.

# %%
list(lca.dicts.product.reversed.items())[:5]
# Out:
# [(0, 309634890161917952),
#  (1, 309634890161917953),
#  (2, 309634890161917954),
#  (3, 309634890161917955),
#  (4, 309634890161917956)]

# %%
list(lca.dicts.activity.reversed.items())[:5]
# Out:
# [(0, 309634890161917952),
#  (1, 309634890161917953),
#  (2, 309634890161917954),
#  (3, 309634890161917955),
#  (4, 309634890161917956)]

# %%
list(lca.dicts.biosphere.reversed.items())[:5]
# Out:
# [(0, 1), (1, 2), (2, 3), (3, 4), (4, 5)]

# %% [markdown]
# ### 7.2 Dictionaries that map matrix indices back to Brightway objects
#
# The matrices only know row and column numbers. To go back from those numbers to Brightway nodes, use the dictionaries stored on the LCA object.
#
# As seen above, those giving `id` -> `index` live in `lca.dicts.activity`, `lca.dicts.product`, and `lca.dicts.biosphere`.
# And those giving `index` -> `id` live in `lca.dicts.activity.reversed`, `lca.dicts.product.reversed`, and `lca.dicts.biosphere.reversed`

# %%
selected_activity_index = lca.dicts.activity[selected_activity.id]

pd.DataFrame(
    [
        {
            'dictionary': 'activity',
            'size': len(lca.dicts.activity),
            'example matrix index': selected_activity_index,
            'example node name': bd.get_node(id=lca.dicts.activity.reversed[selected_activity_index])['name'],
        },
        {
            'dictionary': 'product',
            'size': len(lca.dicts.product),
            'example matrix index': demand_index,
            'example node name': bd.get_node(id=lca.dicts.product.reversed[demand_index])['name'],
        },
        {
            'dictionary': 'biosphere',
            'size': len(lca.dicts.biosphere),
            'example matrix index': 0,
            'example node name': bd.get_node(id=lca.dicts.biosphere.reversed[0])['name'],
        },
    ]
)
# Out:
#   dictionary   size  example matrix index  \
# 0   activity  11747                  6885
# 1    product  11747                  6885
# 2  biosphere   1807                     0
#
#                                                                   example node name
# 0  Operation, passenger car, petrol, 15% vol. ETBE with ethanol from biomass, EURO4
# 1  Operation, passenger car, petrol, 15% vol. ETBE with ethanol from biomass, EURO4
# 2                                                                    1,4-Butanediol

# %% [markdown]
# ### 7.3 The technosphere matrix and the biosphere matrix
#
# After `lca.lci()`, Brightway has built:
#
# - `lca.technosphere_matrix`: the technosphere matrix $A$
# - `lca.biosphere_matrix`: the biosphere matrix $B$
#
# For a demanded product, a column of the technosphere matrix shows the products consumed and produced by that unit process. A column of the biosphere matrix shows the direct elementary flows of the corresponding activity.

# %%
pd.DataFrame(
    [
        {'object': 'demand_array', 'shape': lca.demand_array.shape},
        {'object': 'technosphere_matrix', 'shape': lca.technosphere_matrix.shape},
        {'object': 'biosphere_matrix', 'shape': lca.biosphere_matrix.shape},
        {'object': 'supply_array', 'shape': lca.supply_array.shape},
        {'object': 'inventory', 'shape': lca.inventory.shape},
        {'object': 'characterization_matrix', 'shape': lca.characterization_matrix.shape},
        {'object': 'characterized_inventory', 'shape': lca.characterized_inventory.shape},
    ]
)
# Out:
#                     object           shape
# 0             demand_array        (11747,)
# 1      technosphere_matrix  (11747, 11747)
# 2         biosphere_matrix   (1807, 11747)
# 3             supply_array        (11747,)
# 4                inventory   (1807, 11747)
# 5  characterization_matrix    (1807, 1807)
# 6  characterized_inventory   (1807, 11747)

# %%
# Let's slice the technosphere matrix to fetch all the rows (products) 
# at the column corresponding to our gasoline car transport activity.
technosphere_column = lca.technosphere_matrix[:, demand_index].tocoo()
technosphere_column
# Out:
# <11747x1 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2 stored elements in COOrdinate format>

# %%
rev_bio, rev_prod, rev_act = lca.dicts.biosphere.reversed, lca.dicts.product.reversed, lca.dicts.activity.reversed

# %%
# let's map those indices to product names and locations
technosphere_view = pd.DataFrame(
    [
        {
            'row index': row_idx,
            'col index': demand_index,
            'product': bd.get_node(id=rev_prod[row_idx])['name'],
            'location': bd.get_node(id=rev_prod[row_idx]).get('location'),
            'amount in A': amount,
        }
        for row_idx, amount in zip(technosphere_column.row, technosphere_column.data)
    ]
)

technosphere_view.sort_values('amount in A', ascending=False)

# notice how inputs are stored as negative entries in the technosphere/A matrix
# except the outgoing/production exchange, which is positive and on the diagonal (where row index == col index)
# Out:
#    row index  col index  \
# 0       6885       6885
# 1       7272       6885
#
#                                                                             product  \
# 0  Operation, passenger car, petrol, 15% vol. ETBE with ethanol from biomass, EURO4
# 1    Petrol, 15% vol. ETBE additive, EtOH f. biomass, prod. RER, at service station
#
#   location  amount in A
# 0       CH     1.000000
# 1       CH    -0.060379

# %%
# here too, let's slice the biosphere matrix to fetch all the rows (elementary flows) 
# at the column corresponding to our gasoline car transport activity.
biosphere_column = lca.biosphere_matrix[:, selected_activity_index].tocoo()

biosphere_view = pd.DataFrame(
    [
        {
            'row index': row_idx,
            'col index': demand_index,
            'biosphere flow': bd.get_node(id=rev_bio[row_idx])['name'],
            'categories': '::'.join(bd.get_node(id=rev_bio[row_idx]).get('categories') or ()),
            'amount in B': amount,
        }
        for row_idx, amount in zip(biosphere_column.row, biosphere_column.data)
    ]
)

biosphere_view.sort_values('amount in B', ascending=False).head(12)
# Out:
#     row index  col index                                 biosphere flow  \
# 9         714       6885                                    Heat, waste
# 4         637       6885                         Carbon dioxide, fossil
# 3         634       6885                     Carbon dioxide, non-fossil
# 6         644       6885                        Carbon monoxide, fossil
# 15        827       6885  NMVOC, non-methane volatile organic compounds
# 17        837       6885                    Particulate Matter, > 10 um
# 36       1767       6885                                Nitrogen oxides
# 5         641       6885                    Carbon monoxide, non-fossil
# 0         585       6885                                        Ammonia
# 38       1779       6885        Particulate Matter, > 2.5 um and < 10um
# 1         603       6885                                        Benzene
# 37       1776       6885                   Particulate Matter, < 2.5 um
#
#    categories  amount in B
# 9         air     2.723100
# 4         air     0.176730
# 3         air     0.008091
# 6         air     0.000722
# 15        air     0.000093
# 17        air     0.000078
# 36        air     0.000036
# 5         air     0.000033
# 0         air     0.000023
# 38        air     0.000014
# 1         air     0.000009
# 37        air     0.000008

# %% [markdown]
# For this notebook, two practical readings are enough:
#
# - in the technosphere column, the positive diagonal entry is the reference product produced by the activity
# - the other entries are the technosphere inputs used by that activity
# - in the biosphere column, each row is a direct emission or resource use of that activity before upstream scaling

# %% [markdown]
# ### 7.4 Supply array and inventory
#
# `lca.supply_array` indicates how much each activity must run to meet the final demand $$\mathbf{A}\mathbf{s} = \mathbf{f}$$

# %%
# let's print the activities and the amount they must supply to satisfy the functional unit.
nonzero_supply = np.flatnonzero(lca.supply_array)

print(f"Number of supplying activities throughout the system: {nonzero_supply.shape}")

supply_view = pd.DataFrame(
    [
        {
            'activity': bd.get_node(id=lca.dicts.activity.reversed[idx])['name'],
            'location': bd.get_node(id=lca.dicts.activity.reversed[idx]).get('location'),
            'amount in supply_array': lca.supply_array[idx],
        }
        for idx in nonzero_supply
    ]
)

# let's print only the first 12 ones
supply_view.sort_values('amount in supply_array', ascending=False).head(12)

# These are 12 out of many activities along the supply chain that must provide an output to satisfy the functional unit
# Out:
# Number of supplying activities throughout the system: (4282,)
#                                                                               activity  \
# 2725  Operation, passenger car, petrol, 15% vol. ETBE with ethanol from biomass, EURO4
# 4002                                                    Transport, transoceanic tanker
# 3182                                                   Refinery gas, burned in furnace
# 2218                                           Natural gas, high pressure, at consumer
# 2383                                            Natural gas, low pressure, at consumer
# 2243                                           Natural gas, high pressure, at consumer
# 3455                                      Sweet gas, burned in gas turbine, production
# 3542                                            Transport, crude oil pipeline, onshore
# 517                                  Crude oil, market mix, at long distance transport
# 2911            Petrol, 15% vol. ETBE additive, with ethanol from biomass, at refinery
# 2910    Petrol, 15% vol. ETBE additive, EtOH f. biomass, prod. RER, at service station
# 2173                                   Natural gas, burned in industrial furnace 1MWth
#
#      location  amount in supply_array
# 2725       CH                1.000000
# 4002      OCE                0.295077
# 3182      RER                0.108698
# 2218       CH                0.095320
# 2383       CH                0.094030
# 2243       FR                0.086376
# 3455      GLO                0.074381
# 3542      RER                0.069353
# 517       RER                0.061744
# 2911      RER                0.060409
# 2910       CH                0.060379
# 2173       CH                0.052639

# %% [markdown]
# The inventory matrix then scales `lca.biosphere_matrix` by `lca.supply_array` $$\mathbf{G} = \mathbf{B}\,\mathrm{diag}(\mathbf{s})$$
# So summing a row in `lca.biosphere_matrix` gives a cradle-to-gate total for one pollutant.

# %%
noxs = [
    flow
    for flow in bd.Database('ecoinvent-3.10-biosphere')
    if flow['name'] == 'Nitrogen oxides'
]
noxs
# Out:
# ['Nitrogen oxides' (kilogram, None, ('air', 'lower stratosphere + upper troposphere')),
#  'Nitrogen oxides' (kilogram, None, ('air', 'urban air close to ground')),
#  'Nitrogen oxides' (kilogram, None, ('air', 'low population density, long-term')),
#  'Nitrogen oxides' (kilogram, None, ('air', 'non-urban air or from high stacks')),
#  'Nitrogen oxides' (kilogram, None, ('air',))]

# %%
[nox.id for nox in noxs]
# Out:
# [4200, 4197, 4199, 4198, 4201]

# %% [markdown]
# But, let' be careful here: `lca.biosphere_matrix` isn't as large as the `biosphere` database, because `matrix_utils` (a sub-library) only fill in `lca.biosphere_matrix` with flows that are actuall used.

# %%
len(bd.Database('ecoinvent-3.10-biosphere'))
# Out:
# 4362

# %%
lca.biosphere_matrix.shape
# Out:
# (1807, 11747)

# %%
nox_rows = [lca.dicts.biosphere[nox.id] for nox in noxs if nox.id in lca.dicts.biosphere]
nox_rows
# Out:
# [1766, 1764, 1765, 1767]

# %%
print("NOx flow id", " | ", "NOx index in lca.biosphere_matrix")
for flow, flow_idx in zip(noxs, nox_rows):
    print(flow.id, " | ", flow_idx)
# Out:
# NOx flow id  |  NOx index in lca.biosphere_matrix
# 4200  |  1766
# 4197  |  1764
# 4199  |  1765
# 4198  |  1767

# %%
emissions = []
for row in nox_rows:
    flow = bd.get_activity(lca.dicts.biosphere.reversed[row])
    emissions.append(
        [
            flow["name"],
            flow["categories"],
            flow["unit"],
            lca.inventory[row, selected_activity_index]
        ]
    )

print(f"Cradle-to-gate NOx emissions for activity with index {selected_activity_index}.")
pd.DataFrame(emissions, columns=["name", "categories", "unit", "amount"])
# Out:
# Cradle-to-gate NOx emissions for activity with index 6885.
#               name                                     categories      unit  \
# 0  Nitrogen oxides  (air, lower stratosphere + upper troposphere)  kilogram
# 1  Nitrogen oxides               (air, urban air close to ground)  kilogram
# 2  Nitrogen oxides       (air, non-urban air or from high stacks)  kilogram
# 3  Nitrogen oxides                                         (air,)  kilogram
#
#      amount
# 0  0.000000
# 1  0.000000
# 2  0.000000
# 3  0.000036

# %%
emissions = []
for row in nox_rows:
    flow = bd.get_activity(lca.dicts.biosphere.reversed[row])
    emissions.append(
        [
            flow["name"],
            flow["categories"],
            flow["unit"],
            lca.inventory[row, selected_activity_index]
        ]
    )

print(f"Cradle-to-gate NOx emissions for activity with index {selected_activity_index}.")
pd.DataFrame(emissions, columns=["name", "categories", "unit", "amount"])
# Out:
# Cradle-to-gate NOx emissions for activity with index 6885.
#               name                                     categories      unit  \
# 0  Nitrogen oxides  (air, lower stratosphere + upper troposphere)  kilogram
# 1  Nitrogen oxides               (air, urban air close to ground)  kilogram
# 2  Nitrogen oxides       (air, non-urban air or from high stacks)  kilogram
# 3  Nitrogen oxides                                         (air,)  kilogram
#
#      amount
# 0  0.000000
# 1  0.000000
# 2  0.000000
# 3  0.000036

# %% [markdown]
# ### 7.5 Characterized inventory
#
# After `lca.lcia()`, Brightway applies the chosen characterization factors. The matrix `lca.characterized_inventory` has the same shape as `lca.inventory`, but its values are now in impact-score units rather than physical flow units. Summing all its cells gives the LCIA score.

# %%
print('LCA score:', lca.score)
# Out:
# LCA score: 0.2416033568295284

# %%
print('LCA score:', np.sum(lca.characterization_matrix @ lca.inventory))
# Out:
# LCA score: 0.2416033568295284

# %% [markdown]
# Let's sum `lca.characterized_inventory` column-wise (we collapsed activities)

# %%
characterized_by_flow = np.asarray(lca.characterized_inventory.sum(axis=1)).ravel()

# %%
# let's sort them by individual score and remove those that are zero and keep teh ten largest contributors
top_flow_indices = [
    idx for idx 
    in np.argsort(characterized_by_flow) 
    if characterized_by_flow[idx] != 0
]

# let's revert it, because np.argsort sorts ascendingly
top_flow_indices = top_flow_indices[::-1]
# and let's pick the ten largest
top_flow_indices = top_flow_indices[:10]

pd.DataFrame(
    [
        {
            'biosphere flow': bd.get_activity(id=lca.dicts.biosphere.reversed[idx])['name'],
            'categories': '::'.join(bd.get_activity(id=lca.dicts.biosphere.reversed[idx]).get('categories') or ()),
            'characterized contribution': characterized_by_flow[idx],
        }
        for idx in top_flow_indices
    ]
)
# Out:
#            biosphere flow                              categories  \
# 0  Carbon dioxide, fossil                                     air
# 1  Carbon dioxide, fossil          air::urban air close to ground
# 2         Methane, fossil                                     air
# 3  Carbon dioxide, fossil  air::non-urban air or from high stacks
# 4     Dinitrogen monoxide  air::non-urban air or from high stacks
# 5     Dinitrogen monoxide          air::urban air close to ground
# 6         Methane, fossil  air::non-urban air or from high stacks
# 7     Dinitrogen monoxide                                     air
# 8         Methane, fossil          air::urban air close to ground
# 9     Methane, non-fossil  air::non-urban air or from high stacks
#
#    characterized contribution
# 0                    0.179903
# 1                    0.025981
# 2                    0.023498
# 3                    0.008292
# 4                    0.001874
# 5                    0.000811
# 6                    0.000597
# 7                    0.000392
# 8                    0.000070
# 9                    0.000051

# %% [markdown]
# We can also sum row-wise to show the contribution of activities.

# %%
characterized_by_activity = np.asarray(lca.characterized_inventory.sum(axis=0)).ravel()

# %%
# let's sort them by individual score and remove those that are zero and keep teh ten largest contributors
top_flow_indices = [
    idx for idx 
    in np.argsort(characterized_by_activity) 
    if characterized_by_activity[idx] != 0
]

# let's revert it, because np.argsort sorts ascendingly
top_flow_indices = top_flow_indices[::-1]
# and let's pick the ten largest
top_flow_indices = top_flow_indices[:10]

pd.DataFrame(
    [
        {
            'biosphere flow': bd.get_activity(id=lca.dicts.activity.reversed[idx])['name'],
            'categories': '::'.join(bd.get_activity(id=lca.dicts.activity.reversed[idx]).get('categories') or ()),
            'characterized contribution': characterized_by_activity[idx],
        }
        for idx in top_flow_indices
    ]
)
# Out:
#                                                                      biosphere flow  \
# 0  Operation, passenger car, petrol, 15% vol. ETBE with ethanol from biomass, EURO4
# 1                                                               Natural gas, vented
# 2                                                   Refinery gas, burned in furnace
# 3                                      Sweet gas, burned in gas turbine, production
# 4                                    Natural gas, sweet, burned in production flare
# 5                                        Petroleum coke, burned in refinery furnace
# 6                                   Natural gas, burned in industrial furnace 1MWth
# 7                                     Natural gas, burned in industrial furnace 1MW
# 8                                        Heavy fuel oil, burned in refinery furnace
# 9                                                    Transport, transoceanic tanker
#
#   categories  characterized contribution
# 0                               0.177256
# 1                               0.023337
# 2                               0.006502
# 3                               0.004981
# 4                               0.003677
# 5                               0.003096
# 6                               0.002958
# 7                               0.002322
# 8                               0.002205
# 9                               0.001326

# %%
lca.switch_method(bd.methods.random())

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 lcia
#
# NameError: name 'lcia' is not defined

# %% [markdown]
# ## 8) Dedicated `ecoinvent` import overview
#
# In this notebook, we only use the prepared `ecoinvent-3.10-biosphere` project archive as a shortcut for `biosphere3` and the LCIA methods.
# We do not import the `ecoinvent` technosphere database itself.
#
# Key points:
# - `ecoinvent` is not distributed in this repository.
# - The full `ecoinvent 3.12 cutoff` technosphere import is run on Day 2, not in this notebook.
# - The overall logic is the same: create an importer, apply strategies, inspect statistics, then write the database.
# - In practice, `ecoinvent` uses dedicated `bw2io` importers.

# %%
# Example preview. The actual import happens on Day 2.

# bi.import_ecoinvent_release(
#     version="3.12", 
#     system_model="cutoff", # other options are "consequential", "apos" and "EN15804"
#     username="xxxx",
#     password="xxxx",
#     biosphere_name="biosphere" # optional, otherwise a name is chosen for you
# )

# %% [markdown]
# ## 9) Brief troubleshooting notes
#
# - Project install fails: the first run of `bi.remote.install_project(...)` needs an internet connection to download the archive from `https://files.brightway.dev/`.
# - Project already exists: the setup cell switches to the existing local project instead of downloading it again.
# - Incomplete project contents: if the project exists but is missing `biosphere3` or the LCIA methods, delete that project or choose a fresh project name and rerun section 1.
# - Workbook not found: confirm that `data/lci-bafu.xlsx` is present in the repository.
# - `bafu` missing: rerun the BAFU import cells so that the workbook is parsed and written to the project.

# %% [markdown]
# ## Recap
#
# After this notebook, you should now know how to:
#
# - bootstrap a `brightway` project from a prepared archive
# - import a database with `ExcelImporter`
# - inspect the LCIA methods already available in a project
# - import your own LCIA method
# - interpret the role of strategies, matching, and statistics
# - search a database for activities and inspect exchanges
# - run a first LCA from demand to score
# - read `demand_array`, `technosphere_matrix`, `biosphere_matrix`, `supply_array`, and `inventory`
# - use the LCA dictionaries to move between matrix indices and Brightway objects
# - extract cradle-to-gate pollutant totals and interpret `characterized_inventory`
# - recognize how the same import logic would extend to `ecoinvent`
